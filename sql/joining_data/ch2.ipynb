# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Chapter 2

# %%
# %load_ext sql
#%sql sqlite:///leaders.db
# %sql postgresql://datacamp:datacamp@localhost:15432/datacamp
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: datacamp@datacamp'

# %%
# %%sql -- Select the city name (with alias), the country code,
# -- the country name (with alias), the region,
# -- and the city proper population
# SELECT c1.name AS city, code, c2.name AS country,
#        region, city_proper_pop
# -- From left table (with alias)
# FROM cities AS c1
#   -- Join to right table (with alias)
#   INNER JOIN countries AS c2
#     -- Match on country code
#     ON c1.country_code = c2.code
# -- Order by descending country code
# ORDER BY code desc;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 230 rows affected.
# [('Harare', 'ZWE', 'Zimbabwe', 'Eastern Africa', 1606000),
#  ('Lusaka', 'ZMB', 'Zambia', 'Eastern Africa', 1742979),
#  ('Cape Town', 'ZAF', 'South Africa', 'Southern Africa', 3740026),
#  ('Johannesburg', 'ZAF', 'South Africa', 'Southern Africa', 4434827),
#  ('Durban', 'ZAF', 'South Africa', 'Southern Africa', 3442361),
#  ('Ekurhuleni', 'ZAF', 'South Africa', 'Southern Africa', 3178470),
#  ("Sana'a", 'YEM', 'Yemen', 'Middle East', 1937451),
#  ('Ho Chi Minh City', 'VNM', 'Vietnam', 'Southeast Asia', 7681700),
#  ('Hanoi', 'VNM', 'Vietnam', 'Southeast Asia', 6844100),
#  ('Caracas', 'VEN', 'Venezuela', 'South America', 1943901),
#  ('Maracaibo', 'VEN', 'Venezuela', 'South America', 1599940),
#  ('Tashkent', 'UZB', 'Uzbekistan', 'Southern and Central Asia', 2309600),
#  ('Chicago', 'USA', 'United States', 'North America', 2695598),
# ...

# %%
# %%sql SELECT c1.name AS city, code, c2.name AS country,
#        region, city_proper_pop
# FROM cities AS c1
#   -- 1. Join right table (with alias)
#   LEFT JOIN countries AS c2
#     -- 2. Match on country code
#     ON c1.country_code = c2.code
# -- 3. Order by descending country code
# ORDER BY code DESC;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 236 rows affected.
# [('Taichung', None, None, None, 2752413),
#  ('Tainan', None, None, None, 1885252),
#  ('Kaohsiung', None, None, None, 2778918),
#  ('Bucharest', None, None, None, 1883425),
#  ('Taipei', None, None, None, 2704974),
#  ('New Taipei City', None, None, None, 3954929),
#  ('Harare', 'ZWE', 'Zimbabwe', 'Eastern Africa', 1606000),
#  ('Lusaka', 'ZMB', 'Zambia', 'Eastern Africa', 1742979),
#  ('Cape Town', 'ZAF', 'South Africa', 'Southern Africa', 3740026),
#  ('Ekurhuleni', 'ZAF', 'South Africa', 'Southern Africa', 3178470),
#  ('Durban', 'ZAF', 'South Africa', 'Southern Africa', 3442361),
#  ('Johannesburg', 'ZAF', 'South Africa', 'Southern Africa', 4434827),
#  ("Sana'a", 'YEM', 'Yemen', 'Middle East', 1937451),
#  ('Hanoi', 'VNM', 'Vietnam', 'Southeast Asia', 6844100),
#  ('Ho Chi Minh City', 'VNM', 'Vietnam', 'Southeast Asia', 7681700),
# ...

# %%
# %%sql /*
# 5. Select country name AS country, the country's local name,
# the language name AS language, and
# the percent of the language spoken in the country
# */
# SELECT c.name AS country, local_name, l.name AS language, percent
# -- 1. From left table (alias as c)
# FROM countries AS c
#   -- 2. Join to right table (alias as l)
#   inner JOIN languages AS l
#     -- 3. Match on fields
#     ON c.code = l.code
# -- 4. Order by descending country
# ORDER BY country desc;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 914 rows affected.
# [('Zimbabwe', 'Zimbabwe', 'Shona', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tonga', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tswana', None),
#  ('Zimbabwe', 'Zimbabwe', 'Venda', None),
#  ('Zimbabwe', 'Zimbabwe', 'Xhosa', None),
#  ('Zimbabwe', 'Zimbabwe', 'Sotho', None),
#  ('Zimbabwe', 'Zimbabwe', 'sign', None),
#  ('Zimbabwe', 'Zimbabwe', 'Shangani', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndau', None),
#  ('Zimbabwe', 'Zimbabwe', 'Nambya', None),
#  ('Zimbabwe', 'Zimbabwe', 'Koisan', None),
#  ('Zimbabwe', 'Zimbabwe', 'Kalanga', None),
#  ('Zimbabwe', 'Zimbabwe', 'Chibarwe', None),
#  ('Zimbabwe', 'Zimbabwe', 'Chewa', None),
#  ('Zimbabwe', 'Zimbabwe', 'English', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndebele', None),
#  ('Zambia', 'Zambia', 'Lozi', 5.5),
#  ('Zambia', 'Zambia', 'unspecified', 0.2),
#  ('Zambia', 'Zambia', 'Other', 9.7),
#  ('Zambia', 'Zambia', 'Bisa', 1.0),
# ...

# %%
# %%sql /*
# 5. Select country name AS country, the country's local name,
# the language name AS language, and
# the percent of the language spoken in the country
# */
# SELECT c.name AS country, local_name, l.name AS language, percent
# -- 1. From left table (alias as c)
# FROM countries AS c
#   -- 2. Join to right table (alias as l)
#   left JOIN languages AS l
#     -- 3. Match on fields
#     ON c.code = l.code
# -- 4. Order by descending country
# ORDER BY country desc;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 921 rows affected.
# [('Zimbabwe', 'Zimbabwe', 'Chibarwe', None),
#  ('Zimbabwe', 'Zimbabwe', 'Shona', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndebele', None),
#  ('Zimbabwe', 'Zimbabwe', 'English', None),
#  ('Zimbabwe', 'Zimbabwe', 'Chewa', None),
#  ('Zimbabwe', 'Zimbabwe', 'Xhosa', None),
#  ('Zimbabwe', 'Zimbabwe', 'Venda', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tswana', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tonga', None),
#  ('Zimbabwe', 'Zimbabwe', 'Sotho', None),
#  ('Zimbabwe', 'Zimbabwe', 'sign', None),
#  ('Zimbabwe', 'Zimbabwe', 'Shangani', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndau', None),
#  ('Zimbabwe', 'Zimbabwe', 'Nambya', None),
#  ('Zimbabwe', 'Zimbabwe', 'Koisan', None),
#  ('Zimbabwe', 'Zimbabwe', 'Kalanga', None),
#  ('Zambia', 'Zambia', 'Lala', 1.8),
#  ('Zambia', 'Zambia', 'Mambwe', 1.3),
#  ('Zambia', 'Zambia', 'Luvale', 1.5),
#  ('Zambia', 'Zambia', 'English', 1.7),
# ...

# %%
# %%sql -- 5. Select name, region, and gdp_percapita
# SELECT name, region, gdp_percapita
# -- 1. From countries (alias as c)
# FROM countries AS c
#   -- 2. Left join with economies (alias as e)
#   LEFT JOIN economies AS e
#     -- 3. Match on code fields
#     ON c.code = e.code
# -- 4. Focus on 2010
# WHERE year = 2010;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 185 rows affected.
# [('Afghanistan', 'Southern and Central Asia', 539.667),
#  ('Angola', 'Central Africa', 3599.27),
#  ('Albania', 'Southern Europe', 4098.13),
#  ('United Arab Emirates', 'Middle East', 34628.63),
#  ('Argentina', 'South America', 10412.95),
#  ('Armenia', 'Middle East', 3121.78),
#  ('Antigua and Barbuda', 'Caribbean', 13531.78),
#  ('Australia', 'Australia and New Zealand', 56362.84),
#  ('Austria', 'Western Europe', 46757.13),
#  ('Azerbaijan', 'Middle East', 5847.26),
#  ('Burundi', 'Eastern Africa', 242.84),
#  ('Belgium', 'Western Europe', 44691.32),
#  ('Benin', 'Western Africa', 734.278),
#  ('Burkina Faso', 'Western Africa', 588.584),
#  ('Bangladesh', 'Southern and Central Asia', 807.531),
#  ('Bulgaria', 'Eastern Europe', 6743.74),
#  ('Bahrain', 'Middle East', 20823.22),
#  ('Bahamas', 'Caribbean', 22957.79),
#  ('Bosnia and Herzegovina', 'Southern Europe', 4404.37),
# ...

# %%
# %%sql -- Select fields
# SELECT region, avg(gdp_percapita) AS avg_gdp
# -- From countries (alias as c)
# FROM countries AS c
#   -- Left join with economies (alias as e)
#   LEFT JOIN economies AS e
#     -- Match on code fields
#     ON c.code = e.code
# -- Focus on 2010
# WHERE year = 2010
# -- Group by region
# GROUP BY region
# -- Order by descending avg_gdp
# ORDER BY avg_gdp desc;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 23 rows affected.
# [('Western Europe', 58130.9628571429),
#  ('Nordic Countries', 57073.998),
#  ('North America', 47911.51),
#  ('Australia and New Zealand', 44792.385),
#  ('British Islands', 43588.33),
#  ('Eastern Asia', 26205.8516666667),
#  ('Southern Europe', 22926.4109090909),
#  ('Middle East', 18204.6417647059),
#  ('Baltic Countries', 12631.03),
#  ('Caribbean', 11413.3394615385),
#  ('Southeast Asia', 10547.1544),
#  ('Eastern Europe', 10095.4566666667),
#  ('South America', 7420.59916666667),
#  ('Southern Africa', 5051.598),
#  ('Central America', 4969.97),
#  ('Central Africa', 4797.23988888889),
#  ('Northern Africa', 4713.86166666667),
#  ('Micronesia', 4497.652),
#  ('Polynesia', 3451.36333333333),
#  ('Southern and Central Asia', 2797.155),
#  ('Melanesia', 2532.61),
#  ('Eastern Africa', 1757.3481875),
#  ('Western Africa', 998.954875)]

# %%
# %%sql SELECT cities.name AS city, urbanarea_pop, countries.name AS country,
#        indep_year, languages.name AS language, percent
# FROM cities
#   LEFT JOIN countries
#     ON cities.country_code = countries.code
#   LEFT JOIN languages
#     ON countries.code = languages.code
# ORDER BY city, language;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 1375 rows affected.
# [('Abidjan', 4765000, "Cote d'Ivoire", 1960, 'French', None),
#  ('Abidjan', 4765000, "Cote d'Ivoire", 1960, 'Other', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Arabic', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'English', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Hindi', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Persian', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Urdu', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'English', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Fulani', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Hausa', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Igbo', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Other', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Yoruba', None),
#  ('Accra', 2070463, 'Ghana', 1957, 'Akyem', 3.2),
# ...

# %%
# %%sql -- convert this code to use RIGHT JOINs instead of LEFT JOINs
# /*
# SELECT cities.name AS city, urbanarea_pop, countries.name AS country,
#        indep_year, languages.name AS language, percent
# FROM cities
#   LEFT JOIN countries
#     ON cities.country_code = countries.code
#   LEFT JOIN languages
#     ON countries.code = languages.code
# ORDER BY city, language;
# */
#
# SELECT cities.name AS city, urbanarea_pop, countries.name AS country,
#        indep_year, languages.name AS language, percent
# FROM languages
#   RIGHT JOIN countries
#     ON languages.code = countries.code
#   RIGHT JOIN cities
#     ON cities.country_code = countries.code
# ORDER BY city, language;
# Out:
#  * postgresql://datacamp:***@localhost:15432/datacamp
#    sqlite:///leaders.db
# 1375 rows affected.
# [('Abidjan', 4765000, "Cote d'Ivoire", 1960, 'French', None),
#  ('Abidjan', 4765000, "Cote d'Ivoire", 1960, 'Other', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Arabic', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'English', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Hindi', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Persian', None),
#  ('Abu Dhabi', 1145000, 'United Arab Emirates', 1971, 'Urdu', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'English', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Fulani', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Hausa', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Igbo', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Other', None),
#  ('Abuja', 1235880, 'Nigeria', 1960, 'Yoruba', None),
#  ('Accra', 2070463, 'Ghana', 1957, 'Akyem', 3.2),
# ...
