# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Chapter 2

# %%
from collections import Counter

# %%
word_counts = [Counter({'AutoML': 1,
          'DataCamp': 1,
          'H': 2,
          'In': 1,
          'Introduction': 1,
          'O': 2,
          'a': 1,
          'about': 1,
          'and': 1,
          'auto': 1,
          'glimpse': 1,
          'have': 1,
          'its': 1,
          'learn': 1,
          'of': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'will': 1,
          'you': 1}),
 Counter({'DataCamp': 1,
          'Hacking': 1,
          'Learn': 1,
          'Significance': 1,
          'Stocks': 1,
          'Testing': 1,
          'and': 1,
          'co': 1,
          'data': 1,
          'how': 1,
          'manipulate': 1,
          'p': 1,
          'pandas': 1,
          'series': 1,
          'time': 1,
          'to': 1,
          'with': 1}),
 Counter({'#DataCamp': 1,
          '#DataScience': 1,
          '#Python': 1,
          '#sklearn': 1,
          '@cbismuth': 1,
          'Linear': 1,
          'RT': 1,
          'detection': 1,
          'example': 1,
          'features': 1,
          'most': 1,
          'regression': 1,
          'significant': 1,
          'with': 1}),
 Counter({'#DataCamp': 1,
          '#DataScience': 1,
          '#Python': 1,
          '#sklearn': 1,
          'Linear': 1,
          'detection': 1,
          'example': 1,
          'features': 1,
          'most': 1,
          'regression': 1,
          'significant': 1,
          'with': 1}),
 Counter({'#DataCamp': 1,
          '#DataScience': 1,
          '#Python': 1,
          '#sklearn': 1,
          'Basic': 1,
          'example': 1,
          'linear': 1,
          'regression': 1}),
 Counter({'#DataScience': 1,
          '#Datacamp': 1,
          '#Python': 1,
          '@David': 1,
          'Data': 1,
          'I': 1,
          'Introduction': 1,
          'Makinde': 1,
          'Python': 1,
          'RT': 1,
          'Science': 1,
          'completed': 1,
          'for': 1,
          'just': 1,
          'to': 1}),
 Counter({'#DataFramedChallenge': 1,
          'DataCamp': 2,
          'Enter': 1,
          'a': 2,
          'an': 1,
          'be': 1,
          'chance': 1,
          'for': 1,
          'has': 1,
          'on': 1,
          'pod': 1,
          'podcast': 1,
          'segment': 1,
          'the': 1,
          'to': 1,
          'upcoming': 1}),
 Counter({'DataCamp': 1,
          'De': 1,
          'In': 1,
          'Introduction': 1,
          'Metaclasses': 1,
          'Python': 2,
          'about': 1,
          'by': 1,
          'in': 1,
          'learn': 1,
          'll': 1,
          'metaclasses': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'you': 1}),
 Counter({'#DataScience': 1,
          '#Datacamp': 1,
          '#Python': 1,
          'Data': 1,
          'I': 1,
          'Introduction': 1,
          'Python': 1,
          'Science': 1,
          'completed': 1,
          'for': 1,
          'just': 1,
          'to': 1}),
 Counter({'#DataCamp': 1,
          '#Python': 1,
          '#sklearn': 1,
          '@cbismuth': 1,
          'My': 1,
          'RT': 1,
          'classifier': 1,
          'first': 1,
          'pretty': 1}),
 Counter({'#DataCamp': 1,
          '#Python': 1,
          '#sklearn': 1,
          'My': 1,
          'classifier': 1,
          'first': 1,
          'pretty': 1}),
 Counter({'#DataEngineer': 1,
          '#DataScience': 1,
          '#DataScientist': 1,
          '#SoftwareTesting': 1,
          '@ascentt': 1,
          'RT': 1,
          'The': 1,
          'different': 1,
          'job': 1,
          'market': 1,
          'on': 1,
          'roles': 1,
          'the': 1}),
 Counter({'#DataEngineer': 1,
          '#DataScience': 1,
          '#SoftwareTesting': 1,
          'The': 1,
          'different': 1,
          'job': 1,
          'market': 1,
          'on': 1,
          'roles': 1,
          'the': 1}),
 Counter({'Consegu': 1,
          'OPP': 1,
          'a': 1,
          'contacto': 1,
          'de': 4,
          'del': 1,
          'divisi': 1,
          'el': 1,
          'encargadas': 1,
          'gente': 1,
          'gracias': 1,
          'inform': 1,
          'la': 3,
          'las': 1,
          'n': 1,
          'tica': 1,
          'una': 1}),
 Counter({'#datacamp': 1,
          '#podcast': 1,
          'Destruction': 1,
          'Math': 1,
          'Weapons': 1,
          'of': 1}),
 Counter({'Data': 1,
          'DataCamp': 1,
          'In': 1,
          'Kyso': 1,
          'Science': 1,
          'Shareable': 1,
          'and': 1,
          'create': 1,
          'how': 1,
          'learn': 1,
          'll': 1,
          'publishable': 1,
          'reprod': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'with': 1,
          'you': 1}),
 Counter({'A': 1,
          'Studying': 1,
          'be': 1,
          'day': 1,
          'done': 2,
          'every': 1,
          'for': 1,
          'has': 1,
          'how': 1,
          'its': 1,
          'leader': 1,
          'must': 1,
          'next': 1,
          'opportunity': 1,
          'prepare': 1,
          'show': 1,
          'the': 1,
          'to': 1,
          'yourself': 1}),
 Counter({'#datacamp': 1, '#learningR': 1, '#programming': 1, '@DataCamp': 1}),
 Counter({'#DataCamp': 1,
          '#DataScience': 1,
          'DataCamp': 1,
          'Programa': 1,
          'Python': 1,
          'Trilha': 1,
          'com': 1,
          'conclu': 1,
          'da': 1,
          'de': 1,
          'do': 1,
          'em': 1,
          'incr': 1,
          'o': 1,
          'projeto': 1,
          'sucesso': 1,
          'vel': 1}),
 Counter({'#OQueVamosAprenderHoje': 1,
          '#datascience': 1,
          '#dsa': 1,
          'Depois': 1,
          'de': 3,
          'dia': 1,
          'futuro': 1,
          'hora': 1,
          'investir': 1,
          'longo': 1,
          'no': 1,
          'trabalho': 1,
          'um': 1}),
 Counter({'#DataFramedchallenge': 1,
          '#datacamp': 1,
          '#datascience': 1,
          '#empathy': 1,
          '@DataCamp': 1,
          '@charlyingsparks': 1,
          '@hmason': 1,
          '@hugobowne': 1,
          'RT': 1,
          'This': 1,
          'is': 1,
          'on': 1,
          'so': 1,
          'spot': 1}),
 Counter({'@gastronomy': 1,
          'Bayes': 2,
          'Classification': 1,
          'Classifier': 1,
          'DataCamp': 1,
          'Learn': 1,
          'Naive': 2,
          'RT': 1,
          'Scikit': 1,
          'a': 1,
          'and': 1,
          'build': 1,
          'evaluate': 1,
          'how': 1,
          'learn': 1,
          'to': 1,
          'using': 2}),
 Counter({'Bayes': 2,
          'Classifi': 1,
          'Classification': 1,
          'DataCamp': 1,
          'Learn': 1,
          'Naive': 2,
          'Scikit': 1,
          'a': 1,
          'and': 1,
          'build': 1,
          'evaluate': 1,
          'how': 1,
          'learn': 1,
          'to': 1,
          'using': 1}),
 Counter({'#DataFramedchallenge': 1,
          '#datacamp': 1,
          '#datascience': 1,
          '#empathy': 1,
          '@DataCamp': 1,
          '@hmason': 1,
          '@hugobowne': 1,
          'This': 1,
          'is': 1,
          'on': 1,
          'so': 1,
          'spot': 1}),
 Counter({'@venturidb': 1,
          'Data': 1,
          'If': 1,
          'Science': 1,
          'by': 1,
          'classes': 1,
          'learn': 1,
          'of': 1,
          'one': 1,
          'programming': 1,
          'start': 1,
          'these': 1,
          'to': 1,
          'want': 1,
          'with': 1,
          'you': 1}),
 Counter({'#Datacamp': 1,
          '#Shiny': 1,
          '@minebocek': 1,
          'Learning': 1,
          'about': 1,
          'in': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@aaysbt': 1,
          'Day': 1,
          'I': 1,
          'RT': 1,
          'There': 1,
          'brain': 1,
          'completed': 1,
          'course': 1,
          'is': 1,
          'jsut': 1,
          'killing': 1,
          'learn': 1,
          'lot': 1,
          'me': 1,
          'my': 1,
          'of': 1,
          'statistical': 1,
          'the': 1,
          'thingking': 1,
          'thinks': 1,
          'to': 1,
          'was': 1}),
 Counter({'@BernieMat': 1,
          '@DataCamp': 1,
          '@RStudioJoe': 1,
          '@epi': 1,
          '@zabormetrics': 1,
          'twit': 1}),
 Counter({'@DataCamp': 1,
          '@RStudioJoe': 1,
          '@epi': 1,
          '@malco': 1,
          '@zabormetrics': 1,
          'This': 1,
          'You': 1,
          'barrett': 1,
          'have': 1,
          'in': 1,
          'is': 1,
          'just': 1,
          'may': 1,
          'me': 1,
          'months': 1,
          'of': 1,
          'one': 1,
          'perfect': 1,
          'saved': 1,
          'stress': 1,
          'tweet': 1,
          'twit': 1}),
 Counter({'@BernieMat': 1,
          '@DataCamp': 1,
          '@epi': 1,
          'DataCamp': 1,
          'a': 1,
          'analysis': 1,
          'course': 1,
          'has': 1,
          'on': 1,
          'survival': 1,
          'twit': 1}),
 Counter({'@DataCamp': 1,
          '@epi': 1,
          '@malco': 1,
          'And': 1,
          'barrett': 1,
          'extremely': 1,
          'for': 1,
          'helpful': 1,
          'refs': 1,
          'thanks': 1,
          'the': 1,
          'twit': 1}),
 Counter({'@DataCamp': 1,
          '@epi': 1,
          '@malco': 1,
          'I': 1,
          'Stata': 1,
          'Things': 1,
          'analysis': 1,
          'as': 1,
          'barrett': 1,
          'data': 1,
          'for': 1,
          'in': 1,
          'religiously': 1,
          'setting': 1,
          'stset': 1,
          'such': 1,
          'survival': 1,
          'twit': 1,
          'up': 1,
          'use': 1}),
 Counter({'@DataCamp': 1,
          'Bag': 1,
          'I': 1,
          'Mining': 1,
          'Text': 1,
          'Words': 1,
          'can': 1,
          'class': 1,
          'continue': 1,
          'of': 1,
          't': 1,
          'the': 1}),
 Counter({'@BernieMat': 1,
          '@DataCamp': 1,
          '@epi': 1,
          'Data': 1,
          'I': 1,
          'In': 1,
          'R': 1,
          'Science': 1,
          'and': 1,
          'for': 1,
          'general': 1,
          'recommend': 1,
          'twit': 1}),
 Counter({'@khalid': 1,
          'Customizing': 1,
          'Data': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'I': 1,
          'Introduction': 1,
          'P': 1,
          'RT': 1,
          'Visualization': 1,
          'amer': 1,
          'chapter': 1,
          'finished': 1,
          'from': 1,
          'have': 1,
          'of': 1,
          'plots': 1,
          'the': 1,
          'to': 1,
          'with': 1}),
 Counter({'#Py': 1,
          '#metaclasses': 1,
          '@DataCamp': 1,
          'In': 1,
          'Introduction': 1,
          'Metaclasses': 1,
          'New': 1,
          'Python': 1,
          'RT': 1,
          'Tutorial': 1,
          'are': 1,
          'how': 1,
          'implement': 1,
          'in': 1,
          'learn': 1,
          'them': 1,
          'this': 1,
          'to': 2,
          'tutorial': 1,
          'what': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Joining': 1,
          'PostgreSQL': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'@andrewgelman': 1,
          'Business': 1,
          'apologize': 1,
          'customer': 1,
          'do': 1,
          'for': 1,
          'know': 1,
          'need': 1,
          'not': 1,
          'people': 1,
          'the': 1,
          'to': 2,
          'wanting': 1,
          'wants': 1,
          'what': 1,
          'with': 1}),
 Counter({'@andrewgelman': 1,
          'Big': 1,
          'Instead': 1,
          'a': 2,
          'be': 1,
          'convenient': 1,
          'data': 2,
          'get': 1,
          'messy': 1,
          'of': 1,
          'often': 1,
          'random': 1,
          'sample': 2,
          'tends': 1,
          'to': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          'Analyst': 1,
          'Quantitative': 1,
          'R': 1,
          'a': 1,
          'but': 1,
          'curriculum': 1,
          'do': 1,
          'focused': 1,
          'have': 1,
          'mimic': 1,
          'on': 1,
          'suggestion': 1,
          'the': 1,
          'to': 1,
          'track': 1,
          'with': 1,
          'you': 1}),
 Counter({'#MachineLearning': 1,
          '@DataCamp': 1,
          '@mustafanafees': 1,
          'A': 1,
          'And': 1,
          'Data': 1,
          'Programs': 1,
          'RT': 1,
          'Review': 1,
          'Science': 1,
          's': 1}),
 Counter({'@DataCamp': 1,
          '@dataquestio': 1,
          '@drjekyll': 1,
          '@kaggle': 1,
          'I': 1,
          'a': 1,
          'cool': 1,
          'don': 1,
          'give': 1,
          'know': 1,
          'might': 1,
          'ooh': 1,
          'something': 1,
          't': 1,
          'them': 1,
          'try': 1}),
 Counter({'@DataCamp': 1,
          '@dataquestio': 1,
          '@iC': 1,
          'I': 1,
          'and': 1,
          'are': 1,
          'both': 1,
          'courses': 1,
          'dE': 1,
          'doing': 1,
          'free': 1,
          'good': 1,
          'it': 1,
          'm': 1,
          'offer': 1,
          'pipeline': 1,
          'python': 1,
          'really': 1,
          's': 1,
          'that': 1,
          'the': 1}),
 Counter({'@Dame': 1,
          '@DataCamp': 1,
          '@dataquestio': 1,
          '@kaggle': 1,
          'Of': 1,
          'Spades': 1,
          'another': 1,
          'are': 1,
          'both': 1,
          'courses': 1,
          'free': 1,
          'good': 2,
          'is': 1,
          'offer': 1,
          'one': 1,
          'really': 1,
          'that': 1,
          'wi': 1}),
 Counter({'@DataCamp': 1,
          '@NickCarchedi': 1,
          'Data': 1,
          'Great': 1,
          'Intro': 1,
          'SQL': 1,
          'Science': 1,
          'Thanks': 1,
          'and': 1,
          'course': 1,
          'for': 2,
          'to': 1}),
 Counter({'@DataCamp': 1,
          'Activity': 1,
          'Analyzing': 1,
          'In': 1,
          'Police': 1,
          'RT': 1,
          'This': 1,
          'cleaning': 1,
          'cour': 1,
          'course': 1,
          'create': 1,
          'data': 1,
          'll': 1,
          'messy': 1,
          'pandas': 1,
          'practice': 1,
          'this': 1,
          'visualizations': 1,
          'with': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          'Day': 1,
          'I': 1,
          'There': 1,
          'brain': 1,
          'completed': 1,
          'course': 1,
          'is': 1,
          'jsut': 1,
          'learn': 1,
          'lot': 1,
          'my': 1,
          'of': 1,
          'statistical': 1,
          'the': 1,
          'thingking': 1,
          'thinks': 1,
          'to': 1,
          'was': 1}),
 Counter({'#rstats': 1,
          '@gelliottmorris': 1,
          'I': 1,
          'RT': 1,
          'Trying': 1,
          'Want': 1,
          'a': 1,
          'analyze': 1,
          'and': 1,
          'data': 1,
          'dataset': 1,
          'familiar': 1,
          'figure': 1,
          'got': 1,
          'how': 1,
          'learn': 1,
          'out': 1,
          'political': 1,
          'somethi': 1,
          'to': 3,
          've': 1,
          'want': 1}),
 Counter({'@drjekyll': 1,
          'D': 1,
          'Data': 1,
          'DaysOfCode': 1,
          'I': 1,
          'Intro': 1,
          'Python': 1,
          'R': 1,
          'RT': 1,
          'Science': 1,
          'completed': 1,
          'course': 1,
          'for': 1,
          'just': 1,
          'the': 1,
          'to': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Intro': 1,
          'Python': 1,
          'Science': 1,
          'completed': 1,
          'course': 1,
          'for': 1,
          'just': 1,
          'the': 1,
          'to': 1}),
 Counter({'#MachineLearning': 1,
          '@DataCamp': 1,
          'A': 1,
          'And': 1,
          'Data': 1,
          'Programs': 1,
          'Review': 1,
          'Science': 1,
          's': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Importing': 1,
          'Part': 1,
          'Python': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@nnstats': 1,
          'Another': 1,
          'Are': 1,
          'R': 1,
          'RStata': 1,
          'Stata': 1,
          'Tq': 1,
          'any': 1,
          'can': 2,
          'do': 1,
          'for': 1,
          'question': 1,
          'reasons': 1,
          'special': 1,
          't': 1,
          'that': 1,
          'there': 1,
          'things': 1,
          'using': 1}),
 Counter({'#BigData': 1,
          '#DataScience': 1,
          '#Infographic': 1,
          '#Python': 1,
          '@DataCamp': 1,
          'R': 1,
          'battle': 1,
          'by': 1,
          'for': 1,
          'in': 1,
          'supremacy': 1,
          'vs': 1}),
 Counter({'@DataCamp': 1,
          'It': 2,
          'awesome': 2,
          'be': 2,
          'bookmark': 1,
          'could': 2,
          'courses': 1,
          'create': 1,
          'd': 1,
          'even': 1,
          'if': 2,
          'in': 1,
          'interested': 1,
          'more': 1,
          'playlists': 1,
          're': 1,
          'we': 3,
          'would': 1}),
 Counter({'@DataCamp': 1,
          'Data': 1,
          'In': 1,
          'Modeling': 1,
          'Models': 1,
          'RT': 1,
          'Tidyverse': 1,
          'attempt': 1,
          'capture': 1,
          'course': 1,
          'data': 1,
          'in': 1,
          'learn': 1,
          'model': 1,
          'relatio': 1,
          'the': 2,
          'this': 1,
          'to': 2,
          'will': 1,
          'with': 2,
          'you': 1}),
 Counter({'@DataCamp': 1, '@JamesMarsh': 1, 'Thanks': 1}),
 Counter({'@DataCamp': 1,
          '@ShipSystem': 1,
          'I': 1,
          'and': 1,
          'clear': 1,
          'did': 1,
          'directions': 1,
          'interface': 1,
          'most': 1,
          'of': 1,
          'the': 2,
          'think': 1,
          'time': 1,
          'well': 1,
          'were': 1,
          'worked': 1}),
 Counter({'@DataCamp': 1, '@JamesMarsh': 1, 'any': 1, 'feedback': 1}),
 Counter({'#dataframedchallenge': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          'Can': 1,
          'I': 1,
          'and': 1,
          'coming': 1,
          'entering': 1,
          'great': 1,
          'listen': 1,
          'll': 1,
          'm': 1,
          'me': 1,
          'podcasts': 1,
          'see': 1,
          'some': 1,
          't': 1,
          'to': 2,
          'wait': 1,
          'you': 1}),
 Counter({'I': 1,
          'Introduction': 1,
          'R': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@drob': 1,
          'Great': 1,
          'Introduction': 1,
          'Thoroughly': 1,
          'Tidyverse': 1,
          'by': 1,
          'course': 1,
          'enjoyed': 1,
          'instructor': 1,
          'the': 2,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@jenineharris': 1,
          '@old': 1,
          '@venturidb': 1,
          'I': 1,
          'RT': 1,
          'Thank': 1,
          'a': 1,
          'am': 1,
          'and': 1,
          'be': 1,
          'chester': 1,
          'excited': 1,
          'fantastic': 1,
          'for': 1,
          'instructor': 1,
          'man': 1,
          'officially': 1,
          'so': 1,
          'the': 1,
          'to': 2,
          'w': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@jenineharris': 1,
          '@old': 1,
          '@venturidb': 1,
          'Congrats': 1,
          'Dr': 1,
          'HaRRis': 1,
          'WHAT': 1,
          'chester': 1,
          'man': 1}),
 Counter({'@DataCamp': 1,
          'Career': 1,
          'Data': 1,
          'R': 1,
          'Scientist': 1,
          'Thoroughly': 1,
          'Track': 1,
          'course': 1,
          'enjoyed': 1,
          'getting': 1,
          'great': 1,
          'instructors': 1,
          'most': 1,
          'ou': 1,
          'the': 2,
          'with': 1}),
 Counter({'#rstats': 1,
          'I': 1,
          'Trying': 1,
          'Want': 1,
          'a': 1,
          'analyze': 1,
          'and': 1,
          'data': 1,
          'dataset': 1,
          'familiar': 1,
          'figure': 1,
          'got': 1,
          'how': 1,
          'learn': 1,
          'out': 1,
          'political': 1,
          'som': 1,
          'to': 3,
          've': 1,
          'want': 1}),
 Counter({'#lubridate': 1,
          '#stringr': 1,
          '#tidyr': 1,
          '@DataCamp': 1,
          'Cleaning': 1,
          'Data': 1,
          'I': 1,
          'Learned': 1,
          'R': 1,
          'a': 1,
          'and': 1,
          'completed': 1,
          'course': 1,
          'from': 1,
          'functions': 1,
          'in': 1,
          'just': 1,
          'lot': 1,
          'of': 1,
          'packages': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@old': 1,
          'Data': 1,
          'Great': 1,
          'Joining': 1,
          'PostgreSQL': 1,
          'Thoroughly': 1,
          'by': 1,
          'chester': 1,
          'course': 1,
          'enjoyed': 1,
          'in': 1,
          'instructor': 1,
          'man': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          'Did': 1,
          'Pandas': 1,
          'RT': 1,
          'already': 1,
          'basics': 1,
          'cheat': 1,
          'get': 1,
          'sheet': 1,
          'you': 1,
          'your': 1}),
 Counter({'D': 1,
          'Data': 1,
          'DaysOfCode': 1,
          'I': 1,
          'Intro': 1,
          'Python': 1,
          'R': 1,
          'Science': 1,
          'completed': 1,
          'course': 1,
          'for': 1,
          'just': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          'Here': 1,
          'K': 1,
          'Means': 1,
          'Police': 1,
          'UK': 1,
          'analysis': 1,
          'another': 1,
          'applied': 1,
          'clustering': 1,
          'data': 1,
          'introduction': 1,
          's': 1,
          'to': 2}),
 Counter({'@DannyIsSerious': 1,
          '@DataCamp': 1,
          '@nnstats': 1,
          'How': 1,
          'Rstata': 1,
          'good': 1,
          'is': 1,
          'package': 1,
          'the': 1}),
 Counter({'#MachineLearning': 1,
          '#Software': 1,
          '#educ': 1,
          '#tech': 1,
          '#technology': 1,
          '@simplivllc': 1,
          'Certification': 1,
          'Course': 1,
          'OFF': 1,
          'Programming': 1,
          'Python': 1,
          'RT': 1}),
 Counter({'@nnstats': 1,
          'Python': 1,
          'R': 1,
          'RT': 1,
          'been': 1,
          'data': 1,
          'doesn': 1,
          'have': 1,
          'hours': 1,
          'in': 1,
          'last': 1,
          'matter': 1,
          'my': 1,
          'ok': 1,
          'or': 1,
          'questions': 1,
          'responses': 1,
          'science': 1,
          't': 1,
          'that': 1,
          'the': 2,
          'thrown': 1,
          'to': 1,
          'way': 1}),
 Counter({'@DataCamp': 1,
          '@pisastero': 1,
          'I': 1,
          'RT': 1,
          'This': 1,
          'a': 2,
          'and': 1,
          'change': 1,
          'discovered': 1,
          'game': 1,
          'ggthemes': 1,
          'have': 1,
          'hours': 1,
          'is': 1,
          'just': 2,
          'many': 2,
          'million': 1,
          'of': 1,
          'off': 1,
          'paid': 1,
          'the': 1,
          'times': 1,
          've': 1}),
 Counter({'@DataCamp': 1,
          'Dublin': 1,
          'Github': 1,
          'I': 1,
          'Just': 1,
          'a': 1,
          'and': 1,
          'back': 1,
          'expected': 1,
          'far': 1,
          'for': 1,
          'from': 1,
          'got': 1,
          'have': 1,
          'in': 1,
          'less': 1,
          'notifications': 1,
          'only': 1,
          'or': 1,
          'our': 1,
          'so': 1,
          'than': 1,
          'week': 2,
          'with': 1,
          'work': 1}),
 Counter({'@chendaniely': 1,
          '@sctyner': 1,
          'Back': 1,
          'I': 1,
          'RT': 1,
          'Which': 1,
          'and': 1,
          'for': 1,
          'friend': 1,
          'from': 2,
          'get': 1,
          'gift': 1,
          'lovely': 1,
          'me': 2,
          'my': 1,
          'need': 1,
          'reminds': 1,
          'this': 1,
          'to': 1,
          'today': 1,
          'vacation': 1,
          'waiting': 1,
          'was': 1}),
 Counter({'@chendaniely': 1,
          'Back': 1,
          'I': 1,
          'Which': 1,
          'and': 1,
          'for': 1,
          'friend': 1,
          'from': 2,
          'gift': 1,
          'lovely': 1,
          'me': 2,
          'my': 1,
          'reminds': 1,
          'this': 1,
          'today': 1,
          'vacation': 1,
          'waiting': 1,
          'was': 1}),
 Counter({'@DataCamp': 1,
          '@ucl': 1,
          'A': 1,
          'Data': 1,
          'access': 1,
          'biologists': 1,
          'course': 1,
          'for': 2,
          'giving': 1,
          'is': 1,
          'massive': 1,
          'science': 1,
          'thank': 1,
          'their': 1,
          'to': 2,
          'tutorials': 1,
          'underway': 1,
          'us': 1,
          'wonderful': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@DukeSSRI': 1,
          '@rstudio': 1,
          'Causal': 1,
          'Inference': 1,
          'Intro': 1,
          'R': 1,
          'RT': 1,
          'The': 1,
          'a': 1,
          'are': 1,
          'been': 1,
          'developing': 1,
          'first': 1,
          'free': 1,
          'has': 1,
          'https': 1,
          'on': 1,
          'part': 1,
          'parts': 1,
          'series': 1,
          'up': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@jenineharris': 1,
          '@old': 1,
          '@venturidb': 1,
          'Awesome': 1,
          'Congrats': 1,
          'chester': 1,
          'man': 1}),
 Counter({'#Da': 1,
          '#Statistics': 1,
          '#python': 1,
          '@DataCamp': 1,
          '@aaysbt': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'Hypothesis': 1,
          'RT': 1,
          'apart': 1,
          'as': 1,
          'course': 1,
          'examples': 1,
          'of': 1,
          'statictical': 1,
          'test': 1,
          'the': 1,
          'thingking': 1}),
 Counter({'@DataCamp': 1,
          '@old': 1,
          '@venturidb': 1,
          'I': 1,
          'Thank': 1,
          'a': 1,
          'am': 1,
          'and': 1,
          'be': 1,
          'chester': 1,
          'excited': 1,
          'fantastic': 1,
          'instructor': 1,
          'man': 1,
          'officially': 1,
          'so': 1,
          'the': 1,
          'to': 2,
          'you': 1}),
 Counter({'#MachineLearning': 1,
          '#Software': 1,
          '#technology': 1,
          'Certification': 1,
          'Course': 1,
          'OFF': 1,
          'Programming': 1,
          'Python': 1}),
 Counter({'@DataCamp': 1,
          'Data': 1,
          'Google': 1,
          'Intermediate': 1,
          'RT': 1,
          'Science': 1,
          'Sheets': 1,
          'Spreadsheets': 1,
          'This': 1,
          'You': 1,
          'course': 1,
          'data': 1,
          'deep': 1,
          'dive': 1,
          'expand': 1,
          'for': 1,
          'into': 1,
          'll': 1,
          'vocabulary': 1,
          'will': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          'Learn': 1,
          'Pivot': 1,
          'RT': 1,
          'Spreadsheets': 1,
          'Tables': 1,
          'as': 1,
          'data': 1,
          'example': 1,
          'filtering': 1,
          'real': 1,
          'sorting': 1,
          'subtotaling': 1,
          'such': 1,
          'techniques': 1,
          'using': 1,
          'with': 1,
          'world': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          'Could': 1,
          'RT': 1,
          'TensorBoard': 2,
          'This': 1,
          'a': 1,
          'allows': 1,
          'fantastic': 1,
          'guide': 1,
          'help': 1,
          'how': 1,
          'is': 1,
          'on': 1,
          'that': 1,
          'to': 1,
          'tutorial': 1,
          'use': 1,
          'utility': 1,
          'which': 1,
          'will': 1,
          'you': 2}),
 Counter({'#python': 1,
          '@DataCamp': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'Hypothesis': 1,
          'apart': 1,
          'as': 1,
          'course': 1,
          'examples': 1,
          'of': 1,
          'statictical': 1,
          'test': 1,
          'the': 1,
          'thingking': 1}),
 Counter({'A': 1,
          'Approach': 1,
          'I': 1,
          'Network': 1,
          'R': 1,
          'Science': 1,
          'Tidy': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@nnstats': 1,
          'Datacamp': 1,
          'an': 1,
          'bc': 1,
          'conflicts': 1,
          'environment': 1,
          'had': 1,
          'manages': 1,
          'never': 1,
          'nice': 1,
          'or': 1,
          'package': 1,
          'set': 1,
          'to': 1,
          'up': 1,
          'version': 1,
          'was': 1,
          'you': 1}),
 Counter({'#CodeNe': 1,
          '#python': 1,
          '@DataCamp': 1,
          '@aaysbt': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'RT': 1,
          'a': 1,
          'as': 1,
          'bootstrap': 1,
          'confidence': 1,
          'course': 1,
          'in': 1,
          'intervals': 1,
          'of': 1,
          'part': 1,
          'statistical': 1,
          'the': 1,
          'thinking': 1}),
 Counter({'@DataCamp': 1,
          'Can': 1,
          'I': 1,
          'It': 1,
          'Request': 1,
          'a': 1,
          'am': 1,
          'are': 1,
          'been': 1,
          'days': 1,
          'guys': 1,
          'has': 1,
          'issues': 1,
          'more': 1,
          'not': 1,
          'resolving': 1,
          'than': 1,
          'the': 1,
          'waiting': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          'Are': 1,
          'DataCamp': 1,
          'Get': 1,
          'R': 1,
          'RT': 1,
          'cheat': 1,
          'copy': 1,
          'data': 1,
          'here': 1,
          'in': 1,
          'manipulating': 1,
          'of': 1,
          's': 1,
          'series': 1,
          'sheet': 1,
          'time': 1,
          'with': 1,
          'xts': 2,
          'you': 1,
          'your': 1}),
 Counter({'@AndroidCiudadan': 1,
          '@DataCamp': 1,
          'Data': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'I': 1,
          'R': 1,
          'RT': 1,
          'been': 1,
          'courses': 1,
          'data': 1,
          'fun': 1,
          'grinding': 1,
          'having': 1,
          'python': 1,
          'science': 1,
          'the': 2,
          've': 1,
          'with': 2}),
 Counter({'@DataCamp': 1,
          'Data': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'I': 1,
          'R': 1,
          'been': 1,
          'courses': 1,
          'd': 1,
          'fun': 1,
          'grinding': 1,
          'having': 1,
          'python': 1,
          'science': 1,
          'the': 2,
          've': 1,
          'with': 2}),
 Counter({'Data': 1,
          'I': 1,
          'Joining': 1,
          'PostgreSQL': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'#Bayes': 1,
          '#Classifier': 1,
          '#Naive': 1,
          '@DataCamp': 1,
          'Bayes': 1,
          'Classification': 1,
          'Learn': 1,
          'Naive': 1,
          'New': 1,
          'RT': 1,
          'Scikit': 1,
          'Tutorial': 1,
          'a': 1,
          'and': 1,
          'build': 1,
          'evaluate': 1,
          'how': 1,
          'learn': 1,
          'to': 1,
          'usin': 1,
          'using': 1}),
 Counter({'@DataCamp': 1,
          '@nnstats': 1,
          'Can': 1,
          'R': 1,
          'SAP': 1,
          'analytics': 1,
          'hockey': 1,
          'run': 1}),
 Counter({'@AcademicChatter': 1,
          '@DataCamp': 1,
          '@MBMiller': 1,
          'AT': 1,
          'Hope': 1,
          'You': 1,
          'helps': 1,
          're': 1,
          'that': 1,
          'welcome': 1}),
 Counter({'@AcademicChatter': 1,
          '@DataCamp': 1,
          '@PNgsabrina': 1,
          'Great': 1,
          'thanks': 1}),
 Counter({'@AcademicChatter': 1,
          '@DataCamp': 1,
          '@MBMiller': 1,
          'AT': 1,
          'Highly': 1,
          'They': 1,
          'and': 1,
          'conso': 1,
          'detail': 1,
          'have': 1,
          'practices': 1,
          'recommend': 1,
          'to': 1,
          'tutorials': 1,
          'video': 1}),
 Counter({'#Data': 1,
          '#Datascience': 1,
          '#Numpy': 1,
          '#Pandas': 1,
          '#Python': 1,
          '@DataCamp': 1,
          'Good': 1,
          'for': 1,
          'learners': 1,
          'of': 1,
          'tool': 1}),
 Counter({'@DataCamp': 1,
          '@nnstats': 1,
          'Do': 1,
          'Python': 1,
          'R': 1,
          'Twitter': 1,
          'a': 1,
          'for': 1,
          'or': 1,
          'question': 1,
          'survey': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          '@nnstats': 1,
          'I': 1,
          'like': 1,
          'post': 1,
          'this': 1}),
 Counter({'@DataCamp': 1,
          '@kyso': 1,
          'Data': 1,
          'Learn': 1,
          'New': 1,
          'RT': 1,
          'Science': 1,
          'Shareable': 1,
          'Tutorial': 1,
          'and': 1,
          'create': 1,
          'data': 1,
          'how': 1,
          'io': 1,
          'on': 1,
          'publishable': 1,
          'reproducible': 1,
          'science': 1,
          'studies': 1,
          'to': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@PREDStotheCUP': 1,
          '@nnstats': 1,
          'Something': 1,
          'pirates': 1,
          'say': 1}),
 Counter({'@CodeNewbies': 1,
          '@DataCamp': 1,
          'A': 2,
          'Just': 1,
          'Looking': 1,
          'courses': 1,
          'down': 1,
          'during': 1,
          'finished': 1,
          'keep': 1,
          'my': 1,
          'on': 1,
          'semester': 1,
          'the': 1,
          'time': 1,
          'to': 1,
          'up': 1,
          'working': 1}),
 Counter({'#rstats': 1,
          '@DataCamp': 1,
          'I': 1,
          'This': 1,
          'a': 2,
          'and': 1,
          'changer': 1,
          'discovered': 1,
          'game': 1,
          'ggthemes': 1,
          'have': 1,
          'hours': 1,
          'is': 1,
          'just': 2,
          'many': 2,
          'million': 1,
          'of': 1,
          'off': 1,
          'paid': 1,
          'the': 1,
          'times': 1,
          've': 1}),
 Counter({'#python': 1,
          '@DataCamp': 1,
          'Day': 1,
          'a': 1,
          'as': 1,
          'bootstrap': 1,
          'confidence': 1,
          'course': 1,
          'in': 1,
          'intervals': 1,
          'of': 1,
          'part': 1,
          'statistical': 1,
          'the': 1,
          'thinking': 1}),
 Counter({'@Rick': 1,
          '@datacamp': 1,
          'Data': 1,
          'I': 1,
          'Scavetta': 1,
          'The': 1,
          'Visualization': 1,
          'and': 1,
          'course': 1,
          'd': 1,
          'finished': 1,
          'ggplot': 1,
          'of': 1,
          'on': 1,
          'parts': 1,
          'recently': 1,
          'with': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          'Bivariate': 1,
          'Distribution': 1,
          'Heatmaps': 1,
          'Learn': 1,
          'R': 1,
          'RT': 1,
          'Tutorial': 1,
          'between': 1,
          'features': 1,
          'how': 2,
          'in': 2,
          'relationship': 1,
          'show': 1,
          'the': 1,
          'they': 1,
          'to': 1,
          'two': 1,
          'visually': 1}),
 Counter({'@DataCamp': 1,
          '@nnstats': 1,
          'can': 1,
          'find': 1,
          'i': 1,
          'numbies': 1,
          'the': 1,
          'where': 1}),
 Counter({'@DataCamp': 1,
          '@nnstats': 1,
          'Am': 1,
          'I': 2,
          'RStata': 1,
          'So': 1,
          'but': 1,
          'can': 1,
          'doesn': 1,
          'exploring': 1,
          'generate': 1,
          'graphical': 1,
          'it': 2,
          'like': 1,
          'look': 1,
          'm': 1,
          'missing': 1,
          'output': 1,
          'package': 1,
          'something': 1,
          't': 1,
          'the': 1}),
 Counter({'#R': 1,
          '@DataCamp': 1,
          'Any': 1,
          'DS': 1,
          'Hello': 1,
          'I': 1,
          'R': 1,
          'by': 1,
          'community': 1,
          'course': 1,
          'for': 1,
          'getting': 1,
          'into': 1,
          'm': 1,
          'play': 1,
          'projects': 1,
          'some': 1,
          'tips': 1,
          'to': 1,
          'with': 1}),
 Counter({'@DataCamp': 1, 'I': 1, 'also': 1, 'for': 1, 'vouch': 1}),
 Counter({'@DataCamp': 1, '@nnstats': 1, 'R': 1, 'What': 1, 'is': 1}),
 Counter({'Python': 1,
          'R': 1,
          'been': 1,
          'data': 1,
          'does': 1,
          'have': 1,
          'hours': 1,
          'in': 1,
          'last': 1,
          'my': 1,
          'ok': 1,
          'or': 1,
          'questions': 1,
          'responses': 1,
          'science': 1,
          'that': 1,
          'the': 2,
          'thrown': 1,
          'to': 1,
          'way': 1}),
 Counter({'@DataCamp': 1,
          'Hi': 1,
          'a': 1,
          'all': 1,
          'customer': 1,
          'do': 1,
          'for': 1,
          'have': 1,
          'number': 1,
          'phone': 1,
          'service': 1,
          'y': 1}),
 Counter({'#DataScience': 1,
          '#Python': 1,
          '#learningcurve': 1,
          '#machinelearning': 1,
          '@DataCamp': 1,
          '@iPablo': 1,
          'I': 1,
          'Pandas': 1,
          'RT': 1,
          'completed': 1,
          'course': 1,
          'foundation': 1,
          'just': 1,
          'on': 1,
          'the': 1}),
 Counter({'#DataScience': 1,
          '#Python': 1,
          '#learningcurve': 1,
          '#machinelearning': 1,
          '@DataCamp': 1,
          'I': 1,
          'Pandas': 1,
          'completed': 1,
          'course': 1,
          'foundation': 1,
          'just': 1,
          'on': 1,
          'the': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Importing': 1,
          'Part': 1,
          'Python': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'#Python': 1,
          '@DataCamp': 1,
          'RT': 1,
          'This': 1,
          'analysis': 1,
          'basics': 1,
          'cheat': 1,
          'data': 1,
          'handy': 1,
          'need': 1,
          'one': 1,
          'page': 1,
          'perform': 1,
          'presents': 1,
          'sheet': 1,
          'that': 1,
          'the': 1,
          'to': 1,
          'you': 1}),
 Counter({'@DataCamp': 2,
          '@OyewoleIsmail': 1,
          'All': 1,
          'Data': 1,
          'Journey': 1,
          'RT': 1,
          'Science': 1,
          'Thanks': 1,
          'Yes': 1,
          'and': 1,
          'days': 1,
          'for': 1,
          'instructors': 1,
          'learning': 1,
          'of': 1,
          'on': 1,
          'over': 1,
          't': 1,
          'the': 1}),
 Counter({'#Data': 1,
          '@BCBreeden': 1,
          '@DataCamp': 1,
          'During': 1,
          'Going': 1,
          'I': 1,
          'RT': 1,
          'and': 1,
          'break': 1,
          'courses': 1,
          'data': 1,
          'imports': 1,
          'my': 1,
          'on': 1,
          'sharp': 1,
          'some': 1,
          'stay': 1,
          'tackle': 1,
          'to': 2,
          'visualization': 1,
          'want': 1,
          'winter': 1}),
 Counter({'During': 1,
          'Going': 1,
          'I': 1,
          'and': 1,
          'break': 1,
          'courses': 1,
          'data': 1,
          'imports': 1,
          'my': 1,
          'on': 1,
          'sharp': 1,
          'some': 1,
          'stay': 1,
          'tackle': 1,
          'to': 2,
          'visualization': 1,
          'want': 1,
          'winter': 1}),
 Counter({'@DataCamp': 1,
          'I': 1,
          'One': 1,
          'Second': 1,
          'Third': 1,
          'books': 1,
          'continue': 1,
          'day': 3,
          'days': 1,
          'fo': 1,
          'have': 1,
          'i': 1,
          'my': 3,
          'read': 1,
          'split': 1,
          'time': 1,
          'to': 1,
          'try': 1,
          'when': 1,
          'work': 1}),
 Counter({'Foundations': 1,
          'I': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'pandas': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          'I': 2,
          'Though': 1,
          'above': 1,
          'am': 1,
          'asked': 1,
          'by': 1,
          'for': 1,
          'genuinely': 1,
          'grateful': 1,
          'integrate': 1,
          'opportunity': 1,
          'share': 1,
          'the': 2,
          'to': 2,
          'tweet': 1,
          'was': 1}),
 Counter({'@AlenaShiryaev': 1,
          '@DataCamp': 1,
          '@mona': 1,
          'Keep': 1,
          'You': 1,
          'a': 1,
          'an': 1,
          'by': 1,
          'coming': 1,
          'course': 1,
          'eye': 1,
          'follow': 1,
          'for': 1,
          'great': 1,
          'khm': 1,
          'out': 1,
          're': 1,
          'soon': 1,
          'up': 1,
          'welcome': 1}),
 Counter({'@DataCamp': 1,
          'a': 1,
          'aprender': 1,
          'aprovechar': 1,
          'de': 1,
          'esta': 1,
          'hay': 1,
          'jeje': 1,
          'lo': 1,
          'm': 1,
          'o': 1,
          'que': 1,
          's': 1,
          'si': 1,
          'tanto': 1,
          'vez': 1}),
 Counter({'#gradschool': 1,
          '#gradstudentlife': 1,
          '#whyme': 1,
          '@DataCamp': 1,
          'When': 1,
          'ads': 1,
          'getting': 1,
          'kpop': 1,
          'on': 1,
          'start': 1,
          'videos': 1,
          'you': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          '@robinson': 1,
          'DataCamp': 1,
          'RT': 1,
          'Watch': 1,
          'a': 3,
          'at': 1,
          'brief': 1,
          'by': 1,
          'concept': 1,
          'data': 1,
          'es': 1,
          'give': 1,
          'introduction': 1,
          'new': 1,
          'of': 1,
          'scientist': 1,
          'the': 2,
          'to': 1,
          'webinar': 1,
          'who': 1,
          'will': 1}),
 Counter({'@DataCamp': 1,
          '@old': 1,
          'Data': 1,
          'Great': 1,
          'Joining': 1,
          'PostgreSQL': 1,
          'Thoroughly': 1,
          'by': 1,
          'chester': 1,
          'course': 1,
          'enjoyed': 1,
          'in': 1,
          'instructor': 1,
          'man': 1,
          'the': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Part': 1,
          'Python': 1,
          'Science': 1,
          'Toolbox': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'the': 1}),
 Counter({'#DataFramedChallenge': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@muxevola': 1,
          '@wesmckinn': 1,
          'If': 1,
          'Pandas': 1,
          'RT': 1,
          'assumption': 1,
          'built': 1,
          'data': 1,
          'fits': 1,
          'in': 2,
          'is': 1,
          'memory': 1,
          'that': 1,
          'to': 1,
          'want': 1,
          'you': 1}),
 Counter({'#tidyverse': 1,
          '@DataCamp': 1,
          'Course': 1,
          'Data': 1,
          'New': 1,
          'R': 1,
          'RT': 1,
          'Througho': 1,
          'Tidyverse': 1,
          'Working': 1,
          'You': 1,
          'data': 1,
          'from': 1,
          'in': 2,
          'learn': 1,
          'll': 1,
          'the': 2,
          'to': 1,
          'tools': 1,
          'using': 1,
          'with': 2,
          'work': 1}),
 Counter({'@MercyMarkus': 1,
          'Data': 1,
          'I': 1,
          'Importing': 1,
          'Part': 1,
          'Python': 1,
          'RT': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'@AngeBassa': 1,
          '@DataCamp': 1,
          '@RikaGorn': 1,
          'DataFramed': 1,
          'Just': 1,
          'RT': 1,
          'Taking': 1,
          'a': 2,
          'brilliant': 1,
          'def': 1,
          'during': 1,
          'first': 1,
          'for': 1,
          'is': 1,
          'listened': 1,
          'me': 1,
          'notes': 1,
          'on': 1,
          'podcas': 1,
          'podcast': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@MercyMarkus': 1,
          'Am': 1,
          'Congrats': 1,
          'block': 1,
          'coming': 1,
          'for': 1,
          'me': 1,
          'oh': 1,
          'teach': 1,
          'to': 2,
          'you': 2}),
 Counter({'Data': 1,
          'I': 1,
          'Importing': 1,
          'Part': 1,
          'Python': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Importing': 1,
          'Part': 1,
          'Python': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          'Classroom': 1,
          'DataCamp': 1,
          'Find': 1,
          'about': 1,
          'class': 1,
          'for': 1,
          'generously': 1,
          'is': 1,
          'more': 1,
          'my': 1,
          'out': 1,
          'supporting': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@old': 1,
          'Data': 1,
          'Great': 1,
          'Joining': 1,
          'PostgreSQL': 1,
          'Thoroughly': 1,
          'by': 1,
          'chester': 1,
          'course': 1,
          'enjoyed': 1,
          'in': 1,
          'instructor': 1,
          'man': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          'I': 1,
          'My': 1,
          'an': 1,
          'annual': 1,
          'any': 1,
          'as': 1,
          'automatically': 1,
          'did': 1,
          'email': 1,
          'not': 1,
          'prior': 1,
          'renewed': 1,
          'subscription': 1,
          'such': 1,
          'want': 1,
          'warning': 1,
          'without': 1}),
 Counter({'@DataCamp': 1, 'Any': 1, 'coming': 1, 'sales': 1}),
 Counter({'In': 1,
          'Work': 1,
          'a': 1,
          'addition': 1,
          'and': 1,
          'be': 1,
          'credentials': 1,
          'earn': 1,
          'language': 1,
          'my': 3,
          'on': 2,
          'other': 1,
          'own': 1,
          'programming': 1,
          'projects': 1,
          'still': 1,
          'to': 1,
          'work': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Part': 1,
          'Python': 1,
          'Science': 1,
          'Toolbox': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@ProjectJupyter': 1,
          '@codingphase': 1,
          'Mind': 1,
          'blown': 1}),
 Counter({'@AngeBassa': 1,
          '@DataCamp': 2,
          '@RikaGorn': 1,
          '@iRobot': 1,
          'I': 1,
          'This': 1,
          'actually': 1,
          'definitely': 1,
          'episodes': 1,
          'from': 1,
          'memorable': 1,
          'my': 1,
          'of': 1,
          'sho': 1,
          'was': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Intermediate': 1,
          'Python': 1,
          'Science': 1,
          'completed': 1,
          'course': 1,
          'for': 1,
          'just': 1,
          'the': 1}),
 Counter({'#Day': 1,
          '#Python': 1,
          '@DataCamp': 1,
          '@ProjectJupyter': 1,
          'Also': 1,
          'RT': 1,
          'THIS': 1,
          'break': 1,
          'material': 1,
          'my': 1,
          'reference': 1,
          'routine': 1,
          'to': 1,
          'up': 1}),
 Counter({'#Day': 1,
          '#Python': 1,
          '@DataCamp': 1,
          '@ProjectJupyter': 1,
          'Also': 1,
          'THIS': 1,
          'break': 1,
          'material': 1,
          'my': 1,
          'reference': 1,
          'routine': 1,
          'to': 1,
          'up': 1}),
 Counter({'@AngeBassa': 1, '@DataCamp': 1, '@RikaGorn': 1, '@iRobot': 1}),
 Counter({'@DataCamp': 1,
          '@Kunkakom': 1,
          '@aecoppock': 1,
          '@maqartan': 1,
          'A': 1,
          'Christmas': 1,
          'DeclareDesign': 1,
          'On': 1,
          'RT': 1,
          'Santa': 1,
          'Thank': 1,
          'close': 1,
          'course': 1,
          'intro': 1,
          'is': 1,
          'my': 1,
          'to': 1,
          'wishlist': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@Kunkakom': 1,
          '@maqartan': 1,
          'That': 1,
          'We': 1,
          'a': 1,
          'and': 1,
          'fantastic': 1,
          'he': 1,
          'idea': 1,
          'it': 1,
          'll': 1,
          'north': 1,
          's': 1,
          'says': 1,
          'see': 1,
          'send': 1,
          'up': 1,
          'what': 1}),
 Counter({'@DataCamp': 1,
          '@aecoppock': 1,
          '@maqartan': 1,
          'A': 1,
          'Christmas': 1,
          'DeclareDesign': 1,
          'On': 1,
          'Santa': 1,
          'Thank': 1,
          'close': 1,
          'course': 1,
          'intro': 1,
          'is': 1,
          'my': 1,
          'to': 1,
          'wishlist': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@jpls': 1,
          'Definitely': 1,
          'a': 1,
          'didn': 1,
          'email': 1,
          'get': 1,
          'reminder': 1,
          't': 1}),
 Counter({'@DataCamp': 1,
          '@shankarSRC': 1,
          'I': 1,
          'in': 1,
          'm': 1,
          'no': 1,
          'reminder': 1,
          'renewal': 1,
          'same': 1,
          'situation': 1,
          'the': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@jpls': 1,
          'CC': 1,
          'Guess': 1,
          'I': 2,
          'dispute': 1,
          'have': 2,
          'it': 1,
          'll': 1,
          'my': 1,
          'no': 1,
          'problem': 1,
          'refund': 1,
          'same': 1,
          'the': 1,
          'to': 1,
          'with': 1}),
 Counter({'@AngeBassa': 1,
          '@DataCamp': 1,
          'DataFra': 1,
          'Just': 1,
          'Taking': 1,
          'a': 2,
          'brilliant': 1,
          'def': 1,
          'during': 1,
          'first': 1,
          'for': 1,
          'is': 1,
          'listened': 1,
          'me': 1,
          'notes': 1,
          'on': 1,
          'podcast': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@venturidb': 1,
          'An': 1,
          'DataCamp': 2,
          'Introduction': 1,
          'New': 1,
          'Project': 1,
          'Projects': 1,
          'RT': 1,
          'by': 1,
          'introduction': 1,
          'll': 1,
          'projects': 1,
          'th': 1,
          'through': 1,
          'to': 2,
          'walk': 1,
          'we': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          'Thanks': 1,
          'annual': 1,
          'for': 1,
          'refunding': 1,
          'subscription': 1,
          'the': 1,
          'unintentional': 1}),
 Counter({'@DataCamp': 1,
          '@capigian': 1,
          'Analytics': 1,
          'Classroom': 1,
          'Excited': 1,
          'Predictive': 1,
          'RT': 1,
          'They': 1,
          'be': 1,
          'class': 1,
          'education': 1,
          'for': 2,
          'free': 1,
          'in': 2,
          'my': 1,
          'support': 1,
          'the': 1,
          'this': 1,
          'to': 1,
          'using': 1,
          'via': 1}),
 Counter({'Blended': 1,
          'Data': 1,
          'Leuphana': 1,
          'Science': 1,
          'bir': 1,
          'g': 1,
          'haber': 1,
          'i': 1,
          'in': 1,
          'k': 1,
          'learning': 1,
          'niversitesi': 1,
          'premium': 1,
          'rs': 1,
          's': 1,
          'yelik': 1,
          'zel': 1,
          'zerine': 1}),
 Counter({'@DataCamp': 2,
          'All': 1,
          'Data': 1,
          'Journey': 1,
          'Science': 1,
          'Thanks': 1,
          'Yes': 1,
          'and': 1,
          'days': 1,
          'instructors': 1,
          'learning': 1,
          'of': 1,
          'on': 1,
          'over': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          'Analytics': 1,
          'Classroom': 1,
          'Excited': 1,
          'Predictive': 1,
          'They': 1,
          'be': 1,
          'class': 1,
          'education': 1,
          'for': 2,
          'free': 1,
          'in': 1,
          'my': 1,
          'support': 1,
          'the': 1,
          'to': 1,
          'using': 1,
          'v': 1}),
 Counter({'#pytorchudacityscholar': 1,
          '@DataCamp': 1,
          '@hahaha': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'Just': 1,
          'Nothing': 1,
          'RT': 1,
          'Some': 1,
          'challenge': 1,
          'chugg': 1,
          'either': 1,
          'i': 1,
          'in': 1,
          'is': 1,
          'it': 1,
          'significant': 1,
          'some': 1}),
 Counter({'@DataCamp': 1,
          '@drob': 1,
          'Great': 1,
          'Introduction': 1,
          'Thoroughly': 1,
          'Tidyverse': 1,
          'by': 1,
          'course': 1,
          'enjoyed': 1,
          'instructor': 1,
          'the': 2,
          'to': 1}),
 Counter({'#DataScience': 1,
          'Advice': 1,
          'Applying': 1,
          'Jobs': 1,
          'for': 1,
          'to': 1}),
 Counter({'@DataCamp': 1, '@techmariah': 1, 'Yes': 1}),
 Counter({'#WomenWhoCode': 1,
          '@DataCamp': 1,
          '@hahaha': 1,
          'Inspired': 1,
          'Keep': 1,
          'by': 1,
          'challenge': 1,
          'continue': 1,
          'do': 1,
          'i': 1,
          'is': 1,
          'it': 2,
          'other': 1,
          'seeing': 1,
          'the': 1,
          'to': 1,
          'up': 1,
          'women': 1}),
 Counter({'#pytorchudacityscholar': 1,
          '@DataCamp': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'Just': 1,
          'Nothing': 1,
          'Some': 1,
          'c': 1,
          'challenge': 1,
          'either': 1,
          'in': 1,
          'significant': 1,
          'some': 1}),
 Counter({'@AndroidCiudadan': 1,
          '@DataCamp': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'I': 3,
          'R': 1,
          'RT': 1,
          'Today': 1,
          'a': 1,
          'about': 1,
          'and': 1,
          'course': 1,
          'data': 1,
          'learned': 1,
          'matplotlib': 1,
          'numpy': 1,
          'of': 1,
          'on': 1,
          'science': 1,
          'started': 1}),
 Counter({'@DataCamp': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'I': 2,
          'R': 1,
          'Today': 1,
          'a': 1,
          'about': 1,
          'an': 1,
          'course': 1,
          'data': 1,
          'learned': 1,
          'matplotlib': 1,
          'numpy': 1,
          'of': 1,
          'on': 1,
          'science': 1,
          'started': 1}),
 Counter({'@DataCamp': 1,
          'If': 1,
          'algebra': 1,
          'always': 1,
          'can': 1,
          'down': 1,
          'football': 1,
          'game': 1,
          'has': 1,
          'here': 1,
          'learn': 1,
          'linear': 1,
          'some': 1,
          'this': 1,
          'you': 2}),
 Counter({'@hugobowne': 1,
          'If': 1,
          'Me': 1,
          'Nearly': 2,
          'RT': 1,
          'WT': 1,
          'You': 1,
          'everybody': 2,
          'in': 1,
          'learning': 1,
          'machine': 1,
          'production': 1,
          'python': 1,
          're': 1,
          'run': 1,
          'to': 1,
          'use': 1,
          'want': 1,
          'wrong': 1,
          'you': 2}),
 Counter({'#Python': 1,
          '#datavisualization': 1,
          '@DaveRubal': 1,
          'Bokeh': 1,
          'RT': 1,
          'datasets': 1,
          'enables': 1,
          'high': 1,
          'in': 1,
          'is': 1,
          'large': 1,
          'library': 1,
          'moder': 1,
          'of': 1,
          'performance': 1,
          'presentation': 1,
          'that': 1,
          'the': 1,
          'visual': 1}),
 Counter({'@DataCamp': 1,
          '@tyleransom': 1,
          'Check': 1,
          'I': 1,
          'R': 1,
          'RT': 1,
          'be': 1,
          'causal': 1,
          'courses': 1,
          'created': 1,
          'd': 1,
          'free': 1,
          'if': 1,
          'in': 1,
          'inference': 1,
          'on': 2,
          'out': 1,
          'team': 1,
          'that': 1,
          'the': 1,
          'them': 1,
          'these': 1,
          'they': 1,
          'think': 1,
          'was': 1,
          'you': 1}),
 Counter({'#DataScience': 1,
          '#pyth': 1,
          '@DataCamp': 1,
          '@aaysbt': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'Parameter': 1,
          'RT': 1,
          'Statistical': 1,
          'and': 1,
          'by': 1,
          'estimation': 1,
          'for': 1,
          'learning': 1,
          'optimization': 1,
          'thinking': 1}),
 Counter({'@charlyingsparks': 1,
          '@datacamp': 1,
          '@hugobowne': 1,
          'First': 1,
          'RT': 1,
          'We': 1,
          'and': 1,
          'can': 1,
          'do': 1,
          'excitement': 1,
          'for': 1,
          'foremost': 1,
          'forget': 1,
          'fun': 1,
          'have': 1,
          'in': 1,
          'it': 1,
          'just': 1,
          'keep': 1,
          't': 1,
          'to': 1,
          'we': 1,
          'what': 1,
          'your': 1}),
 Counter({'@datacamp': 1,
          '@hugobowne': 1,
          'First': 1,
          'We': 1,
          'and': 1,
          'can': 1,
          'do': 1,
          'excitement': 1,
          'for': 1,
          'foremost': 1,
          'forget': 1,
          'fun': 1,
          'have': 1,
          'in': 1,
          'just': 1,
          'keep': 1,
          't': 1,
          'to': 1,
          'we': 1,
          'what': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          '@drob': 1,
          'I': 2,
          'all': 1,
          'assessment': 1,
          'at': 1,
          'by': 2,
          'follow': 1,
          'gonna': 1,
          'good': 1,
          'got': 1,
          'if': 1,
          'lesson': 1,
          'mark': 1,
          'my': 1,
          'thanks': 1,
          'them': 1,
          'to': 1,
          've': 1,
          'your': 1}),
 Counter({'@DataCamp': 1, 'New': 1, 'Tutorial': 1, 'on': 1, 'posted': 1}),
 Counter({'@DataCamp': 1,
          'Auto': 1,
          'Automated': 1,
          'Keras': 1,
          'Learn': 1,
          'Learning': 1,
          'Machine': 1,
          'New': 1,
          'RT': 1,
          'Tutorial': 1,
          'about': 1,
          'and': 1,
          'automated': 1,
          'be': 1,
          'can': 1,
          'done': 1,
          'how': 1,
          'it': 1,
          'learning': 1,
          'machine': 1,
          'using': 1,
          'with': 1}),
 Counter({'@BecomingDataSci': 1,
          '@DataCamp': 1,
          '@dsimposters': 1,
          'I': 1,
          'Thank': 1,
          'appreciate': 1,
          'input': 1,
          'much': 1,
          'very': 1,
          'you': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          '@jpls': 1,
          'Same': 1,
          'also': 1,
          'bad': 1,
          'business': 1,
          'but': 1,
          'here': 1,
          'intentions': 1,
          'is': 1,
          'not': 1,
          'off': 1,
          'only': 1,
          'practices': 1,
          'rip': 1,
          'shows': 1,
          'the': 1,
          'this': 1,
          'to': 1,
          'true': 1}),
 Counter({'@DataCamp': 1,
          'I': 2,
          'all': 1,
          'are': 1,
          'as': 1,
          'be': 1,
          'but': 1,
          'company': 1,
          'for': 1,
          'going': 1,
          'guys': 1,
          'had': 1,
          'much': 1,
          'of': 1,
          'respect': 1,
          'ruined': 1,
          'se': 1,
          'so': 1,
          'they': 1,
          'to': 1,
          'today': 1,
          'when': 1,
          'you': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          'Any': 1,
          'Hi': 1,
          'I': 2,
          'Thanks': 1,
          'any': 1,
          'are': 1,
          'can': 1,
          'chance': 1,
          'coming': 1,
          'cyber': 1,
          'get': 1,
          'it': 1,
          'missed': 1,
          'monday': 1,
          'or': 1,
          'other': 1,
          'sale': 1,
          'sales': 1,
          'still': 1,
          'the': 1,
          'there': 1,
          'up': 1}),
 Counter({'@DataCamp': 1,
          '@drob': 1,
          'Great': 1,
          'Introduction': 1,
          'Thoroughly': 1,
          'Tidyverse': 1,
          'Welcome': 1,
          'by': 1,
          'course': 1,
          'enjoyed': 1,
          'instructor': 1,
          'the': 2,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@GalarnykMichael': 1,
          '@PurpleBooth': 1,
          '@vivekkhetan': 1,
          '@willems': 1,
          'I': 1,
          'Thanks': 1,
          'and': 1,
          'have': 1,
          'ism': 1,
          'ju': 1,
          'karlijn': 1,
          're': 1,
          'right': 1,
          'think': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@GalarnykMichael': 1,
          '@PurpleBooth': 1,
          '@markchand': 2,
          '@willems': 1,
          'Great': 1,
          'Keep': 1,
          'doing': 1,
          'it': 1,
          'karlijn': 1,
          'with': 1,
          'work': 1}),
 Counter({'@DataCamp': 1,
          '@GalarnykMichael': 1,
          '@PurpleBooth': 1,
          '@vivekkhetan': 1,
          '@willems': 1,
          'Good': 1,
          'I': 1,
          'Thanks': 1,
          'ism': 1,
          'it': 1,
          'karlijn': 1,
          'mostly': 1,
          'questions': 1,
          'wrote': 1}),
 Counter({'@DataCamp': 1,
          '@JimSpeckart': 1,
          '@mattmasten': 1,
          'MVPs': 1,
          'and': 1,
          'of': 1,
          'team': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          'Check': 1,
          'I': 1,
          'R': 1,
          'causal': 1,
          'courses': 1,
          'created': 1,
          'free': 1,
          'if': 1,
          'in': 1,
          'inference': 1,
          'on': 2,
          'out': 1,
          't': 1,
          'team': 1,
          'that': 1,
          'the': 1,
          'them': 1,
          'these': 1,
          'think': 1,
          'was': 1,
          'you': 1}),
 Counter({'@DataCamp': 1, '@aaysbt': 1, 'Kudos': 1}),
 Counter({'@DataCamp': 1,
          '@drob': 1,
          'Great': 1,
          'I': 1,
          'Introduction': 1,
          'Thoroughly': 1,
          'Tidyverse': 1,
          'am': 1,
          'by': 1,
          'course': 1,
          'enjoyed': 1,
          'instructor': 1,
          'left': 1,
          'the': 2,
          'to': 1,
          'wonderi': 1}),
 Counter({'@DataCamp': 1,
          '@MercyMarkus': 1,
          'I': 1,
          'Thank': 1,
          'check': 1,
          'go': 1,
          'it': 1,
          'll': 1,
          'ok': 1,
          'out': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@itsDonmonc': 1,
          'Just': 1,
          'access': 1,
          'content': 1,
          'course': 1,
          'first': 1,
          'll': 1,
          'module': 1,
          'need': 1,
          'of': 1,
          'pay': 1,
          'rest': 1,
          'the': 3,
          'to': 2,
          'you': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Intro': 1,
          'Python': 1,
          'Science': 1,
          'completed': 1,
          'course': 1,
          'for': 1,
          'just': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@MercyMarkus': 1,
          'courses': 1,
          'free': 1,
          'is': 1,
          'of': 1,
          'one': 1,
          'their': 1,
          'this': 1,
          'under': 1}),
 Counter({'#Python': 1,
          '#datavisualization': 1,
          'Bokeh': 1,
          'datasets': 1,
          'enables': 1,
          'high': 1,
          'is': 1,
          'large': 1,
          'library': 1,
          'of': 1,
          'performance': 1,
          'presentation': 1,
          'that': 1,
          'the': 1,
          'visual': 1}),
 Counter({'@DataCamp': 1,
          'Extremely': 1,
          'Help': 1,
          'angry': 1,
          'article': 1,
          'auto': 1,
          'my': 1,
          'renewed': 1,
          'see': 1,
          'subscription': 1,
          'that': 1,
          'to': 1,
          'today': 1,
          'warning': 1,
          'without': 1,
          'yearly': 1}),
 Counter({'#DataScience': 1,
          '@DataCamp': 1,
          'Day': 1,
          'Parameter': 1,
          'Statistical': 1,
          'and': 1,
          'by': 1,
          'estimation': 1,
          'for': 1,
          'learning': 1,
          'optimization': 1,
          'thinking': 1}),
 Counter({'#moreplease': 1,
          '@DataCamp': 1,
          '@juliasilge': 1,
          'Loved': 1,
          'R': 1,
          'Shakespeare': 1,
          'mining': 1,
          'on': 1,
          'outfit': 1,
          'particularly': 1,
          'text': 2,
          'the': 1,
          'tidy': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          'But': 1,
          'Data': 1,
          'I': 2,
          'Science': 1,
          'You': 1,
          'a': 1,
          'again': 2,
          'anytime': 1,
          'consider': 1,
          'good': 1,
          'have': 1,
          'll': 1,
          'product': 1,
          'studying': 1,
          'subscribe': 1,
          'to': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@GalarnykMichael': 1,
          '@markchand': 1,
          '@vivekkhetan': 1,
          '@willems': 1,
          'Great': 1,
          'You': 1,
          'a': 1,
          'approachable': 1,
          'have': 1,
          'ism': 1,
          'karlijn': 1,
          'very': 1,
          'work': 1,
          'wr': 1}),
 Counter({'@DataCamp': 1,
          'Data': 1,
          'Joining': 1,
          'Learned': 1,
          'PostgreSQL': 1,
          'Thoroughly': 1,
          'a': 1,
          'by': 1,
          'course': 1,
          'enjoyed': 1,
          'exercises': 1,
          'in': 1,
          'lot': 1,
          'subquerying': 1,
          'the': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@old': 1,
          'Data': 1,
          'Great': 1,
          'Joining': 1,
          'PostgreSQL': 1,
          'Thoroughly': 1,
          'by': 1,
          'chester': 1,
          'course': 1,
          'enjoyed': 1,
          'in': 1,
          'instructor': 1,
          'man': 1,
          'the': 1}),
 Counter({'#Day': 1,
          '#Python': 1,
          '@DataCamp': 1,
          'Less': 1,
          'Methods': 1,
          'More': 3,
          'RT': 1,
          'actual': 1,
          'and': 1,
          'basic': 1,
          'focus': 1,
          'in': 1,
          'more': 1,
          'on': 1,
          'p': 1,
          'programming': 1,
          'review': 1,
          'those': 1,
          'today': 1}),
 Counter({'#Day': 1,
          '@DataCamp': 1,
          'Less': 1,
          'Methods': 1,
          'More': 3,
          'actual': 1,
          'and': 1,
          'bas': 1,
          'focus': 1,
          'in': 1,
          'more': 1,
          'on': 1,
          'programming': 1,
          'review': 1,
          'those': 1,
          'today': 1}),
 Counter({'@CVWickham': 1,
          '@DataCamp': 1,
          'Dates': 1,
          'R': 1,
          'RT': 1,
          'This': 1,
          'Times': 1,
          'Working': 1,
          'and': 2,
          'by': 1,
          'computi': 1,
          'course': 1,
          'essentials': 1,
          'in': 1,
          'manipulating': 1,
          'of': 1,
          'parsing': 1,
          'teaches': 1,
          'the': 1,
          'with': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@nebelgrau': 1,
          'DataFramed': 1,
          'Incorporating': 1,
          'RT': 1,
          'There': 1,
          'a': 1,
          'daily': 1,
          'fro': 1,
          'great': 1,
          'idea': 1,
          'into': 1,
          'learn': 1,
          'much': 1,
          'my': 1,
          's': 2,
          'so': 1,
          'soundstream': 1,
          'this': 1,
          'time': 1,
          'to': 1,
          'was': 1}),
 Counter({'@DataCamp': 1,
          '@charlyingsparks': 1,
          '@hugobowne': 1,
          'I': 2,
          'RT': 1,
          'all': 1,
          'an': 1,
          'data': 1,
          'for': 1,
          'incredible': 1,
          'need': 1,
          'of': 1,
          'openness': 1,
          'opportun': 1,
          'push': 1,
          'really': 1,
          's': 1,
          'there': 1,
          'think': 2,
          'to': 1,
          'we': 1}),
 Counter({'@DataCamp': 1,
          '@PurpleBooth': 1,
          '@markchand': 1,
          '@vivekkhetan': 1,
          '@willems': 1,
          'Its': 1,
          'My': 1,
          'a': 1,
          'advice': 1,
          'blog': 1,
          'is': 1,
          'ism': 1,
          'it': 1,
          'karlijn': 1,
          'nice': 1,
          'only': 1,
          'put': 1,
          'to': 1,
          'ty': 1}),
 Counter({'#Python': 1,
          'I': 2,
          'Internet': 1,
          'What': 1,
          'With': 1,
          'a': 1,
          'do': 1,
          'learn': 1,
          'm': 1,
          'so': 1,
          't': 1,
          'thanks': 1,
          'thing': 1,
          'think': 1,
          'to': 1,
          'trying': 1,
          'wrote': 1,
          'you': 1}),
 Counter({'@mkuehn': 1,
          'Foundations': 1,
          'Functional': 1,
          'I': 1,
          'Programming': 1,
          'RT': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'of': 1,
          'purrr': 1,
          'the': 1,
          'with': 1}),
 Counter({'Foundations': 1,
          'Functional': 1,
          'I': 1,
          'Programming': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'of': 1,
          'purrr': 1,
          'the': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          'I': 2,
          'all': 1,
          'an': 1,
          'data': 1,
          'for': 1,
          'incredible': 1,
          'need': 1,
          'of': 1,
          'openness': 1,
          'oppor': 1,
          'push': 1,
          'really': 1,
          's': 1,
          'there': 1,
          'think': 2,
          'to': 1,
          'we': 1}),
 Counter({'@DataCamp': 1, '@LukeNdatigh': 1, 'Thank': 1, 'you': 1}),
 Counter({'@DataCamp': 1,
          'DataFramed': 1,
          'Incorporating': 1,
          'There': 1,
          'a': 1,
          'daily': 1,
          'great': 1,
          'idea': 1,
          'into': 1,
          'learn': 1,
          'much': 1,
          'my': 1,
          's': 2,
          'so': 1,
          'soundstream': 1,
          't': 1,
          'this': 1,
          'to': 1,
          'was': 1}),
 Counter({'@DataCamp': 1, '@MercyMarkus': 1, 'Congratulations': 1}),
 Counter({'@DataCamp': 1,
          'Hello': 1,
          'I': 1,
          'customer': 1,
          'like': 1,
          'service': 1,
          'speak': 1,
          'to': 2,
          'would': 1}),
 Counter({'@DataCamp': 1,
          'Thank': 1,
          'an': 1,
          'dropped': 1,
          'email': 1,
          'you': 1}),
 Counter({'#datacamp': 1, '#learningR': 1, '#programming': 1, '@DataCamp': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          'I': 1,
          'check': 1,
          'everyone': 1,
          'first': 1,
          'for': 1,
          'number': 1,
          'of': 1,
          'page': 1,
          'people': 1,
          'suggest': 1,
          'support': 1,
          'to': 1,
          'would': 1,
          'your': 1}),
 Counter({'@DataCamp': 1, '@MercyMarkus': 1, 'Sist': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          'Every': 1,
          'I': 1,
          'This': 1,
          'an': 1,
          'business': 1,
          'conduct': 1,
          'did': 1,
          'is': 2,
          'no': 1,
          'othe': 1,
          'response': 1,
          'there': 1,
          'unethical': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Importing': 1,
          'Part': 1,
          'Python': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'#Python': 1,
          '#machinelearning': 1,
          '@DataCamp': 1,
          'RT': 1,
          'Scikit': 1,
          'cheat': 1,
          'learn': 1,
          'sheet': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          'Datacamp': 1,
          'Please': 1,
          'courses': 1,
          'deducted': 1,
          'do': 1,
          'fraud': 1,
          'from': 1,
          'money': 1,
          'my': 1,
          'not': 1,
          'subscribe': 1,
          'this': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@DukeSSRI': 1,
          'Causal': 1,
          'Inference': 1,
          'R': 1,
          'The': 1,
          'a': 1,
          'are': 1,
          'been': 1,
          'developing': 1,
          'first': 1,
          'free': 1,
          'has': 1,
          'on': 1,
          'part': 1,
          'parts': 1,
          'series': 1,
          'up': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          'auto': 1,
          'can': 1,
          'cancel': 1,
          'got': 1,
          'please': 1,
          'processed': 1,
          'subscription': 1,
          'the': 1,
          'today': 1,
          'which': 1,
          'you': 1}),
 Counter({'#Day': 1,
          '#Python': 1,
          '@DataCamp': 1,
          '@dcodermobile': 1,
          'More': 1,
          'a': 1,
          'both': 1,
          'calling': 1,
          'coding': 1,
          'from': 1,
          'functions': 1,
          'go': 1,
          'index': 1,
          'on': 1,
          'the': 1,
          'using': 1,
          'while': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          'Netflix': 1,
          'You': 1,
          'guys': 1,
          'hooked': 1,
          'keep': 1,
          'me': 1,
          'more': 1,
          'than': 1}),
 Counter({'@dataiku': 1,
          'Being': 1,
          'Learn': 1,
          'RT': 1,
          'a': 1,
          'about': 2,
          'all': 1,
          'answers': 1,
          'data': 1,
          'giving': 1,
          'guiding': 1,
          'how': 1,
          'instead': 1,
          'isn': 1,
          'it': 1,
          'manager': 1,
          's': 1,
          'science': 1,
          't': 2,
          'team': 1,
          'the': 1,
          'them': 1,
          'there': 1,
          'your': 1}),
 Counter({'@CucubanoPod': 1,
          '@DarknetDiaries': 1,
          '@DataCamp': 1,
          '@TalkPython': 1,
          '@USTpodcast': 1,
          '@nicholdav': 1,
          '@pgmid': 1,
          '@thedollop': 1,
          '@twimlai': 1,
          'OK': 1,
          'Weird': 1,
          'but': 1,
          'flex': 1}),
 Counter({'@KirkDBorne': 1,
          '@MusicComposer': 1,
          '@Shirastweet': 1,
          '@TeachTheMachine': 1,
          '@alcgroup': 1,
          '@data': 1,
          '@dez': 1,
          '@digitalcloudgal': 1,
          'blanchfield': 1,
          'nerd': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Introduction': 1,
          'Python': 1,
          'Visualization': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'the': 1,
          'to': 1,
          'with': 1}),
 Counter({'@KirkDBorne': 1,
          '@MusicComposer': 1,
          '@NexWebSites': 1,
          '@Shirastweet': 1,
          '@TeachTheMachine': 1,
          '@alcgroup': 1,
          '@data': 1,
          '@dez': 1,
          '@digitalcloudgal': 1,
          '@edXOnlin': 1,
          'RT': 1,
          'blanchfield': 1,
          'nerd': 1}),
 Counter({'@MusicComposer': 1,
          '@NexWebSites': 1,
          '@Shirastweet': 1,
          '@TeachTheMachine': 1,
          '@alcgroup': 1,
          '@data': 1,
          '@dez': 1,
          '@digitalcloudgal': 1,
          'blanchfield': 1,
          'nerd': 1}),
 Counter({'#DataScience': 1,
          '#DevCTraining': 1,
          '@DataCamp': 1,
          '@ikayz': 1,
          'Done': 1,
          'Python': 1,
          'RT': 1,
          'and': 1,
          'cheers': 1,
          'for': 1,
          'running': 1,
          'up': 1,
          'with': 1}),
 Counter({'#DataScience': 1,
          '#DevCTraining': 1,
          '@DataCamp': 1,
          'Done': 1,
          'Python': 1,
          'and': 1,
          'cheers': 1,
          'for': 1,
          'running': 1,
          'up': 1,
          'with': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Intro': 1,
          'Python': 1,
          'Science': 1,
          'completed': 1,
          'course': 1,
          'for': 1,
          'just': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@MihiretuKebede': 1,
          '@thomasp': 1,
          'I': 1,
          'This': 1,
          'Yes': 1,
          'a': 1,
          'appear': 1,
          'courses': 1,
          'current': 1,
          'in': 2,
          'section': 1,
          'the': 1,
          'there': 1,
          'though': 1,
          'was': 1,
          'will': 1}),
 Counter({'#DataFramedchallenge': 1,
          '#datacamp': 1,
          '#datascience': 1,
          '#empathy': 1,
          '@DataCamp': 1,
          '@charlyingsparks': 1,
          '@hmason': 1,
          '@hugobowne': 1,
          'RT': 1,
          'This': 1,
          'is': 1,
          'on': 1,
          'so': 1,
          'spot': 1}),
 Counter({'@DataCamp': 1,
          'Bioinformatics': 1,
          'Excited': 1,
          'R': 1,
          'Thanks': 1,
          'better': 1,
          'biologists': 1,
          'class': 1,
          'for': 1,
          'get': 1,
          'lessons': 1,
          'love': 1,
          'making': 1,
          'my': 1,
          'next': 1,
          'to': 3,
          'use': 1,
          'year': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          '@DerekChia': 1,
          '@mona': 1,
          'Be': 1,
          'Thanks': 1,
          'a': 1,
          'coming': 1,
          'course': 1,
          'follow': 1,
          'for': 1,
          'from': 1,
          'great': 1,
          'khm': 1,
          'lookout': 1,
          'on': 1,
          'soon': 1,
          'the': 1,
          'up': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          '@uomodlamansarda': 1,
          'I': 1,
          'RT': 1,
          'Your': 1,
          'amazing': 1,
          'are': 1,
          'miss': 1,
          'never': 1,
          'one': 1,
          'podcasts': 1}),
 Counter({'#P': 1,
          '#PYTHONPROGRAMMING': 1,
          '@DataCamp': 1,
          '@aaysbt': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'I': 1,
          'Part': 1,
          'Python': 1,
          'RT': 1,
          'Statistical': 1,
          'Thinking': 1,
          'been': 1,
          'complete': 1,
          'course': 1,
          'have': 1,
          'in': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@hahaha': 1,
          'I': 1,
          'as': 1,
          'finished': 1,
          'i': 1,
          'is': 1,
          'it': 1,
          'just': 1,
          'lesson': 1,
          'well': 1}),
 Counter({'@DataCamp': 1,
          '@DollaSignBeezy': 1,
          '@nerdnomadmom': 1,
          'Azure': 1,
          'Look': 1,
          'at': 1,
          'certs': 1,
          'the': 1}),
 Counter({'#DataFramedchallenge': 1,
          '#datacamp': 1,
          '#datascience': 1,
          '#empathy': 1,
          '@DataCamp': 1,
          '@hmason': 1,
          '@hugobowne': 1,
          'This': 1,
          'is': 1,
          'on': 1,
          'so': 1,
          'spot': 1}),
 Counter({'@DataCamp': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'I': 1,
          'Part': 1,
          'Python': 1,
          'Statistical': 1,
          'Thinking': 1,
          'been': 1,
          'complete': 1,
          'course': 1,
          'have': 1,
          'in': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          '@muxevola': 1,
          '@wesmckinn': 1,
          'although': 1,
          'doesn': 1,
          'even': 1,
          'fit': 1,
          'if': 1,
          'in': 1,
          'it': 2,
          'memory': 1,
          'should': 1,
          'sometimes': 1,
          't': 1}),
 Counter({'#DataFramedChallenge': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@muxevola': 1,
          '@wesmckinn': 1,
          'Pandas': 1,
          'RT': 1,
          'Swiss': 1,
          'army': 1,
          'being': 1,
          'is': 1,
          'knif': 1,
          'occupying': 1,
          'of': 1,
          'spot': 1,
          'sweet': 1,
          'the': 2,
          'ultimate': 1}),
 Counter({'#DataFramedChallenge': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          '@muxevola': 1,
          'Fairness': 1,
          'RT': 1,
          'a': 1,
          'and': 1,
          'do': 1,
          'incentive': 1,
          'not': 1,
          'proper': 1,
          'seem': 1,
          'to': 1,
          'transparency': 1,
          'undergo': 1}),
 Counter({'@DataCamp': 1,
          '@old': 1,
          'Data': 1,
          'Great': 1,
          'Joining': 1,
          'PostgreSQL': 1,
          'Thoroughly': 1,
          'by': 1,
          'chester': 1,
          'course': 1,
          'enjoyed': 1,
          'in': 1,
          'instructor': 1,
          'man': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@DollaSignBeezy': 1,
          '@nerdnomadmom': 1,
          'Ari': 1,
          'Crazy': 1,
          'I': 1,
          'and': 1,
          'birthday': 1,
          'but': 1,
          'have': 1,
          'lmaoo': 1,
          'random': 1,
          'same': 1,
          'small': 1,
          'the': 1,
          'world': 1}),
 Counter({'@DataCamp': 1,
          '@DollaSignBeezy': 1,
          '@nerdnomadmom': 1,
          'Any': 1,
          'data': 1,
          'hints': 1,
          'how': 1,
          'learn': 1,
          'on': 1,
          'science': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@DollaSignBeezy': 1,
          '@nerdnomadmom': 1,
          'Which': 1,
          'cert': 1,
          'data': 1,
          'for': 2,
          'is': 1,
          'science': 1,
          'security': 1}),
 Counter({'@DataCamp': 1,
          '@nerdnomadmom': 1,
          'Big': 1,
          'Data': 1,
          'Science': 1,
          'That': 1,
          'interesting': 1,
          'one': 1,
          'seems': 1}),
 Counter({'@DataCamp': 1,
          '@iPablo': 1,
          'Congrats': 1,
          'going': 1,
          'keep': 1,
          'on': 1}),
 Counter({'@DataCamp': 1,
          'Disappointed': 1,
          'Having': 1,
          'It': 1,
          'UX': 1,
          'as': 1,
          'auto': 1,
          'bad': 1,
          'been': 1,
          'default': 1,
          'is': 1,
          'of': 1,
          'on': 1,
          'renewal': 1,
          'subscription': 1,
          'turned': 1,
          've': 1,
          'very': 1,
          'would': 1}),
 Counter({'@DataCamp': 1,
          'Just': 1,
          'Programmer': 1,
          'Python': 1,
          'Track': 1,
          'background': 1,
          'cour': 1,
          'finished': 1,
          'have': 1,
          'my': 1,
          'no': 1,
          'related': 1,
          's': 1,
          'the': 1,
          'whatsoever': 1,
          'while': 1,
          'with': 1}),
 Counter({'@jsjoeio': 1,
          'Friends': 1,
          'If': 1,
          'JavaScript': 1,
          'NYC': 1,
          'RT': 1,
          'a': 1,
          'about': 1,
          'and': 1,
          'are': 1,
          'check': 1,
          'education': 1,
          'for': 1,
          'in': 1,
          'job': 1,
          'looking': 2,
          'out': 1,
          'passionate': 1,
          're': 1,
          't': 1,
          'to': 1,
          'who': 1,
          'work': 1,
          'you': 1}),
 Counter({'#DataFramedChallenge': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          'Fairness': 1,
          'a': 1,
          'and': 1,
          'do': 1,
          'incentive': 1,
          'not': 1,
          'proper': 1,
          'seem': 1,
          'transparency': 1}),
 Counter({'#DataFramedChallenge': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@wesmckinn': 1,
          'Pandas': 1,
          'Swiss': 1,
          'being': 1,
          'is': 1,
          'occupying': 1,
          'of': 1,
          'spot': 1,
          'sweet': 1,
          'the': 2,
          'ultimate': 1}),
 Counter({'#DataFramedChallenge': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@wesmckinn': 1,
          'If': 1,
          'Pandas': 1,
          'assumption': 1,
          'built': 1,
          'data': 1,
          'fits': 1,
          'in': 2,
          'is': 1,
          'memory': 1,
          'that': 1,
          'yo': 1}),
 Counter({'@DataCamp': 1,
          'Cyber': 1,
          'Monday': 1,
          'a': 1,
          'code': 1,
          'discount': 1,
          'for': 1,
          'is': 1,
          'there': 1,
          'this': 1,
          'year': 1}),
 Counter({'@DataCamp': 1,
          '@OptimizeRisk': 1,
          '@QuantStratTradR': 1,
          'New': 1,
          'RT': 1,
          'course': 1,
          'from': 1,
          'post': 1,
          's': 1,
          'technology': 1,
          'using': 1}),
 Counter({'#Day': 1,
          '#Python': 1,
          '@DataCamp': 1,
          'Trying': 1,
          'app': 1,
          'benefits': 1,
          'further': 1,
          'gained': 1,
          'go': 1,
          'on': 1,
          'out': 1,
          'repetition': 1,
          'the': 3,
          'through': 1,
          'to': 1,
          'today': 1}),
 Counter({'#DataScience': 1,
          '#dataframedchal': 1,
          '#truth': 1,
          '@DataCamp': 1,
          '@charlyingsparks': 1,
          '@hugobowne': 1,
          '@quaesita': 1,
          'RT': 1,
          'but': 1,
          'cheap': 1,
          'expensive': 1,
          'inspiration': 1,
          'is': 2,
          'rigor': 1}),
 Counter({'#DataScience': 1,
          '#dataframedchallenge': 1,
          '#truth': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@quaesita': 1,
          'but': 1,
          'cheap': 1,
          'expensive': 1,
          'inspiration': 1,
          'is': 2,
          'rigor': 1}),
 Counter({'@DataCamp': 1,
          '@hahaha': 1,
          'Another': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'Feels': 1,
          'Finished': 1,
          'RT': 1,
          'be': 1,
          'challenge': 1,
          'chapter': 1,
          'good': 1,
          'i': 1,
          'in': 1,
          'is': 1,
          'it': 1,
          'lesson': 1,
          'moving': 1,
          'pytorch': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@JamesMarsh': 1,
          'I': 2,
          'R': 1,
          'RT': 1,
          'a': 1,
          'and': 1,
          'been': 2,
          'beginner': 1,
          'courses': 1,
          'for': 1,
          'free': 1,
          'have': 1,
          'in': 1,
          'intuitive': 1,
          'like': 1,
          'me': 1,
          'must': 1,
          'pretty': 1,
          'say': 1,
          'super': 1,
          'they': 1,
          'using': 1,
          've': 1}),
 Counter({'@DataCamp': 1,
          'I': 2,
          'R': 1,
          'a': 1,
          'and': 1,
          'been': 2,
          'beginner': 1,
          'courses': 1,
          'for': 1,
          'free': 1,
          'have': 1,
          'in': 1,
          'intuitive': 1,
          'like': 1,
          'me': 1,
          'must': 1,
          'pretty': 1,
          'say': 1,
          'super': 1,
          'they': 1,
          'using': 1,
          've': 1}),
 Counter({'Friends': 1,
          'If': 1,
          'JavaScript': 1,
          'NYC': 1,
          'a': 1,
          'about': 1,
          'and': 1,
          'are': 1,
          'education': 1,
          'for': 1,
          'in': 1,
          'job': 1,
          'looking': 2,
          'passionate': 1,
          're': 1,
          'to': 1,
          'who': 1,
          'work': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          'Another': 1,
          'Day': 1,
          'DaysOfCode': 1,
          'Feels': 1,
          'Finished': 1,
          'be': 1,
          'challenge': 1,
          'chapter': 1,
          'good': 1,
          'in': 1,
          'lesson': 1,
          'mov': 1,
          'pytorch': 1,
          'the': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@OptimizeRisk': 1,
          'New': 1,
          'course': 1,
          'from': 1,
          'post': 1,
          's': 1,
          'technology': 1,
          'using': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@drivendataorg': 1,
          '@hugobowne': 1,
          '@pjbull': 1,
          'Episode': 1,
          'New': 1,
          'RT': 1,
          'a': 1,
          'and': 1,
          'co': 1,
          'data': 1,
          'for': 1,
          'founder': 1,
          'good': 1,
          'of': 1,
          'scientist': 1,
          'social': 1,
          'speaks': 1,
          'with': 1}),
 Counter({'@DataCamp': 1, '@iPablo': 1, 'Congratulations': 1}),
 Counter({'#Python': 1,
          '#SciPy': 1,
          '@DataCamp': 1,
          'RT': 1,
          'SciPy': 1,
          'This': 1,
          'algebra': 1,
          'basics': 1,
          'cheat': 1,
          'covers': 1,
          'get': 1,
          'in': 1,
          'linear': 1,
          'need': 1,
          'of': 1,
          'sheet': 1,
          'started': 1,
          'that': 1,
          'the': 1,
          'to': 1,
          'you': 1}),
 Counter({'@DarknetDiaries': 1,
          'Apple': 1,
          'Obvs': 1,
          'a': 1,
          'and': 1,
          'anomaly': 1,
          'be': 1,
          'charts': 1,
          'detection': 1,
          'do': 1,
          'easy': 1,
          'how': 1,
          'iTunes': 1,
          'it': 1,
          'scrape': 1,
          'some': 1,
          'the': 1,
          'to': 1,
          'wonder': 1,
          'would': 1}),
 Counter({'@CMastication': 1,
          '@voidspace': 1,
          '@woody': 1,
          'I': 3,
          'able': 1,
          'agree': 1,
          'and': 1,
          'do': 1,
          'google': 1,
          'gsd': 1,
          'just': 1,
          'learn': 1,
          'out': 1,
          'started': 1,
          'th': 1,
          'to': 2,
          'was': 1,
          'ways': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@EconoTodd': 1,
          '@hugobowne': 1,
          'Let': 1,
          'a': 2,
          'all': 1,
          'beer': 1,
          'fan': 1,
          'get': 1,
          'got': 1,
          's': 1,
          'soon': 1,
          've': 1,
          'you': 1}),
 Counter({'Artif': 1,
          'Diferencias': 1,
          'Inteligencia': 1,
          'Una': 1,
          'aprendizaje': 2,
          'autom': 1,
          'de': 1,
          'el': 2,
          'entre': 1,
          'general': 1,
          'la': 1,
          'n': 1,
          'profundo': 1,
          'tico': 1,
          'visi': 1,
          'y': 1}),
 Counter({'@DataCamp': 1,
          '@hugobowne': 1,
          '@math': 1,
          '@muxevola': 1,
          'Fairness': 1,
          'It': 1,
          'RT': 1,
          'a': 2,
          'aggregate': 1,
          'an': 1,
          'at': 1,
          'concept': 1,
          'is': 1,
          'level': 1,
          'need': 1,
          'notion': 1,
          's': 1,
          'statistical': 1,
          'that': 1,
          'to': 1,
          'understand': 1,
          'we': 1}),
 Counter({'@DataCamp': 1,
          '@spenafajuri': 1,
          'Analysing': 1,
          'Clinical': 1,
          'Designing': 1,
          'Hoy': 1,
          'R': 1,
          'RT': 1,
          'Trials': 1,
          'and': 1,
          'curso': 1,
          'en': 1,
          'este': 1,
          'estoy': 1,
          'haciendo': 1,
          'in': 1}),
 Counter({'@DataCamp': 1,
          'Analysing': 1,
          'Clinical': 1,
          'Designing': 1,
          'Hoy': 1,
          'R': 1,
          'Trials': 1,
          'and': 1,
          'curso': 1,
          'en': 1,
          'este': 1,
          'estoy': 1,
          'haciendo': 1,
          'in': 1}),
 Counter({'@DataCamp': 1,
          'Fairness': 1,
          'It': 1,
          'a': 2,
          'aggregate': 1,
          'an': 1,
          'at': 1,
          'concept': 1,
          'is': 1,
          'level': 1,
          'need': 1,
          'notion': 1,
          's': 1,
          'statistical': 1,
          'that': 1,
          'to': 1,
          'understand': 1,
          'we': 1}),
 Counter({'#datascien': 1,
          '@DataCamp': 1,
          '@iPablo': 1,
          'Cleaning': 1,
          'Course': 1,
          'Data': 1,
          'December': 1,
          'I': 1,
          'On': 1,
          'Pandas': 1,
          'Python': 1,
          'RT': 1,
          'completed': 1,
          'foundation': 1,
          'in': 1,
          'of': 1,
          'on': 2,
          'st': 1,
          'the': 2,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@JSnunki': 1,
          'Muy': 1,
          'RT': 1,
          'Thanks': 1,
          'ahora': 1,
          'orgullosa': 1,
          'somos': 1,
          'tal': 1,
          'vez': 1}),
 Counter({'@DataCamp': 1, '@vannyozogu': 1, 'Thank': 1, 'you': 1}),
 Counter({'@DataCamp': 1, '@iPablo': 1, 'Well': 1, 'done': 1}),
 Counter({'@DataCamp': 1, 'useful': 1, 'very': 1}),
 Counter({'@DataCamp': 1,
          'Cleaning': 1,
          'Course': 1,
          'Data': 1,
          'December': 1,
          'I': 1,
          'On': 1,
          'Pandas': 1,
          'Python': 1,
          'completed': 1,
          'foundation': 1,
          'in': 1,
          'of': 1,
          'on': 2,
          'st': 1,
          'the': 2,
          'to': 1}),
 Counter({'#AI': 1,
          '#ArtificialIntelligence': 1,
          '#ML': 1,
          '#MachineIntelligence': 1,
          '#MachineLearning': 1,
          '#developers': 1,
          '#neuralnetwork': 1,
          '#programmers': 1}),
 Counter({'@DataCamp': 1,
          '@malco': 1,
          '@nskajaa': 1,
          'Data': 1,
          'For': 1,
          'I': 1,
          'R': 2,
          'RT': 1,
          'Science': 1,
          'always': 1,
          'and': 1,
          'barrett': 1,
          'for': 1,
          'general': 1,
          'in': 1,
          'learning': 1,
          'recommend': 1}),
 Counter({'@DataCamp': 1,
          'A': 1,
          'Data': 1,
          'Framed': 1,
          'I': 2,
          'and': 1,
          'commentary': 1,
          'enjoying': 1,
          'history': 1,
          'm': 1,
          'mix': 1,
          'much': 1,
          'must': 1,
          'nice': 1,
          'of': 1,
          'podcast': 1,
          'say': 1,
          'that': 1,
          'the': 1,
          'very': 1}),
 Counter({'@DataCamp': 1,
          'I': 2,
          'Minorities': 1,
          'Women': 1,
          'a': 2,
          'already': 1,
          'and': 2,
          'as': 1,
          'completed': 1,
          'of': 1,
          'recipient': 1,
          's': 1,
          'scholarship': 1,
          'selected': 1,
          'though': 1,
          've': 1,
          'was': 1}),
 Counter({'@DataCamp': 1,
          'Data': 1,
          'Demystifying': 1,
          'In': 1,
          'M': 1,
          'Python': 1,
          'RT': 1,
          'Science': 1,
          'about': 1,
          'and': 1,
          'basic': 1,
          'crucial': 1,
          'for': 1,
          'in': 1,
          'learn': 1,
          'required': 1,
          'statistics': 2,
          'the': 1,
          'this': 1,
          'tutorial': 1}),
 Counter({'#codinglife': 1,
          '#javascript': 1,
          '@DataCamp': 1,
          'Amen': 1,
          'CHALLENGE': 1,
          'I': 1,
          'TEMPORARY': 1,
          'absolutely': 1,
          'always': 1,
          'amazing': 1,
          'excited': 1,
          'for': 1,
          'is': 1,
          'm': 1,
          'next': 1,
          'the': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Importing': 1,
          'Part': 1,
          'Python': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          'Facebook': 1,
          'Introduction': 1,
          'Join': 1,
          'RT': 1,
          'Survivors': 1,
          'T': 1,
          'Thursday': 1,
          'Tidyverse': 1,
          'Titanic': 1,
          'a': 1,
          'coding': 1,
          'event': 1,
          'for': 1,
          'live': 1,
          'new': 1,
          'next': 1,
          'of': 1,
          'on': 1,
          'the': 3,
          'to': 1,
          'us': 1}),
 Counter({'#DataScience': 1,
          '#Database': 1,
          '#Python': 1,
          '#day': 1,
          '#developers': 1,
          '#sql': 1,
          '@DataCamp': 1,
          '@HaSN': 1,
          'A': 1,
          'CH': 1,
          'DaysOfCode': 1,
          'RT': 1,
          'on': 1,
          'spent': 1,
          'well': 1}),
 Counter({'@DataCamp': 1,
          '@nskajaa': 1,
          'Data': 1,
          'For': 1,
          'I': 1,
          'R': 2,
          'Science': 1,
          'always': 1,
          'and': 1,
          'for': 1,
          'general': 1,
          'in': 1,
          'learning': 1,
          'recommend': 1}),
 Counter({'#DataScience': 1,
          '#Database': 1,
          '#Python': 1,
          '#day': 1,
          '#developers': 1,
          '#sql': 1,
          '@DataCamp': 1,
          'A': 1,
          'DaysOfCode': 1,
          'on': 1,
          'spent': 1,
          'well': 1}),
 Counter({'I': 1,
          'Markdown': 1,
          'R': 1,
          'Reporting': 1,
          'completed': 1,
          'course': 1,
          'just': 1,
          'the': 1,
          'with': 1}),
 Counter({'@AngeBassa': 1,
          '@DataCamp': 1,
          '@dataelixir': 1,
          'Data': 1,
          'Managing': 1,
          'RT': 1,
          'Science': 1,
          'Teams': 1,
          'via': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@brandibeals': 1,
          'Even': 1,
          'Oh': 1,
          'didn': 1,
          'for': 2,
          'it': 1,
          'me': 1,
          'posting': 1,
          't': 1,
          'thanks': 1,
          'though': 1,
          'well': 1,
          'work': 1}),
 Counter({'Being': 1,
          'a': 1,
          'about': 2,
          'all': 1,
          'answers': 1,
          'data': 1,
          'giving': 1,
          'guiding': 1,
          'instead': 1,
          'isn': 1,
          'it': 1,
          'manager': 1,
          's': 1,
          'science': 1,
          't': 1,
          'team': 1,
          'the': 1,
          'them': 1,
          'there': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          '@doodssiton': 1,
          '@marylvv': 1,
          'Data': 1,
          'Geospatial': 1,
          'Learned': 1,
          'Python': 1,
          'RT': 1,
          'Thank': 1,
          'Visualizing': 1,
          'With': 1,
          'by': 1,
          'course': 1,
          'https': 1,
          'much': 1,
          'sifting': 1,
          'so': 1,
          'the': 1,
          'through': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@Gators': 1,
          '@dataandme': 1,
          '@kearneymw': 1,
          'Thank': 1,
          'for': 1,
          'recommendations': 1,
          'the': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@Mteheran': 1,
          '@calypso': 1,
          'Felicitaciones': 1,
          'RT': 1,
          'bronte': 1}),
 Counter({'@DataCamp': 1,
          '@doodssiton': 1,
          'Glad': 1,
          'hear': 1,
          'this': 1,
          'to': 1}),
 Counter({'#DataScience': 1,
          '@promptcloud': 1,
          'In': 1,
          'RT': 1,
          'a': 1,
          'are': 1,
          'at': 1,
          'blog': 1,
          'buzz': 1,
          'by': 1,
          'case': 1,
          'five': 1,
          'in': 2,
          'listed': 1,
          'look': 1,
          'resources': 1,
          'take': 1,
          'taken': 1,
          'the': 2,
          'this': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@calypso': 1,
          'Felicitaciones': 1,
          'bronte': 1}),
 Counter({'@DataCamp': 1, '@cringngedup': 1, 'Thank': 1, 'you': 1}),
 Counter({'@DataCamp': 1,
          '@iamchantelphd': 1,
          '@kearneymw': 1,
          'I': 2,
          'b': 1,
          'followed': 1,
          'like': 1,
          'method': 1,
          'really': 1,
          'recommend': 1,
          'short': 1,
          'teaching': 1,
          'their': 1,
          'videos': 1,
          'would': 1}),
 Counter({'Analyzing': 1,
          'Data': 1,
          'Election': 1,
          'I': 1,
          'Polling': 1,
          'R': 1,
          'and': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'#DataScience': 1,
          'In': 1,
          'a': 1,
          'are': 1,
          'at': 1,
          'blog': 1,
          'buzz': 1,
          'by': 1,
          'case': 1,
          'five': 1,
          'in': 2,
          'listed': 1,
          'look': 1,
          'resources': 1,
          'take': 1,
          'taken': 1,
          'the': 2,
          'this': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@Ugyen': 1,
          'Congratulations': 1,
          'Norbu': 1,
          'boss': 1}),
 Counter({'#DataChallenge': 1,
          '#DataScience': 1,
          '#DataScientists': 1,
          '#Python': 1,
          '#WomenInTech': 1,
          '@DataCamp': 1,
          '@DataScienceFEM': 2,
          'Fem': 1,
          'RT': 1,
          'Thank': 1,
          'htt': 1,
          'you': 1}),
 Counter({'Data': 1,
          'I': 1,
          'Intermediate': 1,
          'Python': 1,
          'Science': 1,
          'completed': 1,
          'course': 1,
          'for': 1,
          'just': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@marylvv': 1,
          'Data': 1,
          'Geospatial': 1,
          'Learned': 1,
          'Python': 1,
          'Thank': 1,
          'Visualizing': 1,
          'With': 1,
          'by': 1,
          'course': 1,
          'much': 1,
          'sifting': 1,
          'so': 1,
          'the': 1,
          'through': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          'Learning': 1,
          'R': 1,
          'Thanks': 1,
          'app': 1,
          'for': 1,
          'fun': 1,
          'great': 1,
          'is': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@suryast': 1,
          'I': 1,
          'LinkedIn': 1,
          'RT': 1,
          'Your': 1,
          'a': 1,
          'am': 1,
          'app': 1,
          'bug': 1,
          'case': 1,
          'credential': 1,
          'database': 1,
          'has': 1,
          'iOS': 1,
          'in': 2,
          'login': 1,
          'my': 2,
          'registered': 1,
          'using': 1,
          'weird': 1,
          'youe': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          'I': 1,
          'LinkedIn': 1,
          'a': 1,
          'am': 1,
          'app': 1,
          'bug': 1,
          'case': 1,
          'credential': 1,
          'database': 1,
          'has': 1,
          'iOS': 1,
          'in': 2,
          'my': 2,
          'registered': 1,
          'using': 1,
          'weird': 1,
          'youe': 1,
          'your': 1}),
 Counter({'@AngeBassa': 1,
          '@DataCamp': 1,
          'Data': 1,
          'Managing': 1,
          'Science': 1,
          'Teams': 1,
          'via': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          'Muy': 1,
          'Thanks': 1,
          'ahora': 1,
          'orgullosa': 1,
          'somos': 1,
          'tal': 1,
          'vez': 1}),
 Counter({'#DataChallenge': 1,
          '#DataScience': 1,
          '#DataScientists': 1,
          '#Python': 1,
          '#WomenInTech': 1,
          '@DataCamp': 1,
          '@DataScienceFEM': 1,
          'Fem': 1,
          'Thank': 1,
          'you': 1}),
 Counter({'#DataScientists': 1,
          '@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@calypso': 1,
          'Nuestro': 1,
          'RT': 1,
          'bronte': 1,
          'como': 1,
          'con': 1,
          'grado': 1}),
 Counter({'@DataCamp': 1,
          '@drob': 1,
          'Great': 1,
          'Introduction': 1,
          'Tidyverse': 1,
          'by': 1,
          'course': 1,
          'refresher': 1,
          's': 1,
          'the': 1,
          'to': 1}),
 Counter({'#DataScientists': 1,
          '@DataCamp': 1,
          '@DataScienceFEM': 1,
          'Nuestro': 1,
          'como': 1,
          'con': 1,
          'grado': 1}),
 Counter({'@DataScienceFEM': 1,
          '@iris': 1,
          'I': 1,
          'Purpose': 1,
          'RT': 1,
          'am': 1,
          'and': 1,
          'because': 1,
          'dedication': 1,
          'effort': 1,
          'girls': 1,
          'happy': 1,
          'help': 1,
          'my': 1,
          'of': 3,
          'ready': 1,
          'the': 3,
          'to': 1,
          'very': 1}),
 Counter({'@AgroNatureNig': 1, 'RT': 1}),
 Counter({'@Chrismartin': 1,
          '@DataCamp': 1,
          '@Gairan': 1,
          '@JCSkewesDK': 1,
          '@keatonwilson': 1,
          'Datacamp': 1,
          'P': 1,
          'Theory': 1,
          'a': 1,
          'courses': 1,
          'facts': 1,
          'has': 1,
          'million': 1,
          'people': 1,
          'taking': 1,
          'their': 1,
          'vs': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@danielagsrm': 1,
          'Can': 1,
          'RT': 1,
          'Teach': 1,
          'Thank': 1,
          'a': 1,
          'and': 1,
          'believe': 1,
          'change': 1,
          'code': 1,
          'did': 1,
          'girl': 1,
          'it': 1,
          'll': 1,
          'she': 1,
          't': 1,
          'the': 1,
          'to': 1,
          'we': 1,
          'world': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          'Ep': 1,
          'I': 1,
          'In': 1,
          'Math': 1,
          'RT': 1,
          'Season': 1,
          'Weapons': 1,
          'author': 1,
          'finale': 1,
          'of': 4,
          'our': 1,
          'pod': 1,
          'speak': 1,
          'the': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@danielagsrm': 1,
          '@iris': 1,
          'CONGRAAAAATS': 1,
          'RT': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@GarbaAdams': 1,
          '@IamIgoche': 1,
          '@Navas': 1,
          'Congrats': 1,
          'RT': 1,
          'Sofia': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@iris': 1,
          '@stifflerBassMan': 1,
          'Aun': 1,
          'Muchas': 1,
          'RT': 1,
          'Tal': 1,
          'adelante': 1,
          'aplicar': 1,
          'aprender': 1,
          'gracias': 1,
          'm': 2,
          'mucho': 1,
          'necesito': 1,
          'pueda': 1,
          's': 1,
          'vez': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@iris': 2,
          '@stifflerBassMan': 1,
          'RT': 1,
          'interesa': 1,
          'por': 1,
          'si': 1,
          'te': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@stifflerBassMan': 1,
          'Aun': 1,
          'Muchas': 1,
          'Tal': 1,
          'adelante': 1,
          'aplicar': 1,
          'aprender': 1,
          'gracias': 1,
          'm': 2,
          'mucho': 1,
          'necesito': 1,
          'pueda': 1,
          's': 2,
          'vez': 1}),
 Counter({'@DataScienceFEM': 1,
          'Can': 1,
          'Teach': 1,
          'Thank': 1,
          'a': 1,
          'and': 1,
          'believe': 1,
          'change': 1,
          'code': 1,
          'did': 1,
          'girl': 1,
          'it': 1,
          'll': 1,
          'she': 1,
          't': 1,
          'the': 1,
          'to': 1,
          'we': 1,
          'world': 1,
          'you': 1}),
 Counter({'#datachallenge': 1,
          '@DataScienceFEM': 1,
          '@datasciencefem': 1,
          'RT': 1,
          'Today': 1,
          'by': 1,
          'fem': 1,
          'first': 1,
          'fraternity': 1,
          'graduation': 1,
          'of': 2,
          'our': 1,
          'scholarships': 1,
          'sponsored': 1,
          'the': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@iris': 1,
          'CONGRAAAAATS': 1}),
 Counter({'ARE': 1,
          'Analysis': 1,
          'DONE': 1,
          'I': 1,
          'Network': 1,
          'Part': 1,
          'Python': 1,
          'WE': 1,
          'completed': 1,
          'course': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'@Codecademy': 1,
          '@DataCamp': 1,
          '@hackerrank': 1,
          '@mrnavrc': 1,
          'Wor': 1,
          'a': 1,
          'by': 1,
          'can': 1,
          'doing': 1,
          'good': 1,
          'is': 1,
          'learn': 1,
          'make': 1,
          'problems': 1,
          'site': 1,
          'small': 1,
          'that': 1,
          'with': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@DataScienceFEM': 1,
          '@iris': 2,
          'interesa': 1,
          'por': 1,
          'si': 1,
          'te': 1}),
 Counter({'@mrnavrc': 1,
          'I': 3,
          'Python': 1,
          'RT': 1,
          'There': 1,
          'Treehouse': 1,
          'a': 1,
          'and': 1,
          'are': 1,
          'course': 1,
          'didn': 1,
          'format': 1,
          'found': 1,
          'guys': 1,
          'like': 1,
          'many': 1,
          'need': 1,
          'of': 1,
          'out': 1,
          'sorry': 1,
          't': 1,
          'that': 1,
          'the': 2,
          'too': 1,
          'videos': 1}),
 Counter({'I': 2,
          'Python': 1,
          'There': 1,
          'Treehouse': 1,
          'an': 1,
          'are': 1,
          'course': 1,
          'didn': 1,
          'format': 1,
          'found': 1,
          'guys': 1,
          'like': 1,
          'many': 1,
          'of': 1,
          'out': 1,
          'sorry': 1,
          't': 1,
          'that': 1,
          'the': 2,
          'too': 1,
          'videos': 1}),
 Counter({'Deep': 1,
          'Going': 1,
          'I': 1,
          'Learning': 1,
          'Python': 1,
          'completed': 1,
          'course': 1,
          'deeper': 1,
          'in': 1,
          'just': 1,
          'the': 1}),
 Counter({'#Zip': 1,
          '@DataCamp': 1,
          'Files': 2,
          'In': 2,
          'New': 1,
          'Pytho': 1,
          'Python': 1,
          'RT': 1,
          'Tutorial': 1,
          'With': 1,
          'Working': 1,
          'Zip': 1,
          'are': 1,
          'going': 1,
          'how': 1,
          'in': 1,
          'learn': 1,
          'this': 1,
          'to': 2,
          'tutorial': 1,
          'with': 1,
          'work': 1,
          'you': 1}),
 Counter({'#metaclasses': 1,
          'In': 1,
          'Introduction': 1,
          'Metaclasses': 1,
          'New': 1,
          'Python': 1,
          'Tutorial': 1,
          'are': 1,
          'how': 1,
          'implement': 1,
          'learn': 1,
          't': 1,
          'this': 1,
          'to': 2,
          'tutorial': 1,
          'what': 1}),
 Counter({'@abhijitnsharma': 1,
          'Hello': 1,
          'Thank': 1,
          'been': 1,
          'for': 1,
          'has': 1,
          'have': 1,
          'issues': 1,
          'notified': 1,
          'our': 1,
          'patience': 1,
          'resolved': 1,
          'support': 1,
          'team': 1,
          'that': 1,
          'the': 1,
          'us': 1,
          'you': 1,
          'your': 1}),
 Counter({'#rstats': 1,
          '@gelliottmorris': 1,
          'I': 1,
          'RT': 1,
          'Trying': 1,
          'Want': 1,
          'a': 1,
          'analyze': 1,
          'and': 1,
          'data': 1,
          'dataset': 1,
          'familiar': 1,
          'figure': 1,
          'got': 1,
          'how': 1,
          'learn': 1,
          'out': 1,
          'political': 1,
          'somethi': 1,
          'to': 3,
          've': 1,
          'want': 1}),
 Counter({'Activity': 1,
          'Analyzing': 1,
          'In': 1,
          'Police': 1,
          'cleaning': 1,
          'course': 1,
          'create': 1,
          'data': 1,
          'll': 1,
          'messy': 1,
          'pandas': 1,
          'practice': 1,
          'this': 1,
          'visualizations': 1,
          'with': 1,
          'you': 1}),
 Counter({'Data': 1,
          'In': 1,
          'Modeling': 1,
          'Models': 1,
          'Tidyverse': 1,
          'attempt': 1,
          'capture': 1,
          'course': 1,
          'data': 1,
          'in': 1,
          'learn': 1,
          'model': 1,
          't': 1,
          'the': 1,
          'this': 1,
          'to': 2,
          'will': 1,
          'with': 2,
          'you': 1}),
 Counter({'Did': 1,
          'Pandas': 1,
          'already': 1,
          'basics': 1,
          'cheat': 1,
          'get': 1,
          'sheet': 1,
          'you': 1,
          'your': 1}),
 Counter({'Learn': 1,
          'Pivot': 1,
          'Spreadsheets': 1,
          'Tables': 1,
          'as': 1,
          'data': 1,
          'filtering': 1,
          'real': 1,
          'sorting': 1,
          'subtotaling': 1,
          'such': 1,
          'techniques': 1,
          'using': 1,
          'with': 1,
          'wor': 1,
          'your': 1}),
 Counter({'Could': 1,
          'TensorBoard': 2,
          'This': 1,
          'a': 1,
          'fantastic': 1,
          'guide': 1,
          'help': 1,
          'how': 1,
          'is': 1,
          'on': 1,
          'th': 1,
          'to': 1,
          'tutorial': 1,
          'use': 1,
          'utility': 1,
          'which': 1,
          'will': 1,
          'you': 2}),
 Counter({'Data': 1,
          'Google': 1,
          'Intermediate': 1,
          'Science': 1,
          'Sheets': 1,
          'Spreadsheets': 1,
          'This': 1,
          'You': 1,
          'course': 1,
          'deep': 1,
          'dive': 1,
          'expand': 1,
          'for': 1,
          'll': 1,
          'vocabulary': 1,
          'will': 1,
          'your': 1}),
 Counter({'Are': 1,
          'DataCamp': 1,
          'Get': 1,
          'R': 1,
          'cheat': 1,
          'copy': 1,
          'data': 1,
          'here': 1,
          'in': 1,
          'manipulating': 1,
          'of': 1,
          's': 1,
          'series': 1,
          'sheet': 1,
          'time': 1,
          'with': 1,
          'xts': 2,
          'you': 1,
          'your': 1}),
 Counter({'@kyso': 1,
          'Data': 1,
          'Learn': 1,
          'New': 1,
          'Science': 1,
          'Shareable': 1,
          'Tutorial': 1,
          'and': 1,
          'create': 1,
          'data': 1,
          'how': 1,
          'io': 1,
          'publishable': 1,
          'reproducible': 1,
          's': 1,
          'science': 1,
          'to': 1,
          'with': 1}),
 Counter({'@robinson': 1,
          'DataCamp': 1,
          'Watch': 1,
          'a': 3,
          'at': 1,
          'brief': 1,
          'by': 1,
          'concep': 1,
          'data': 1,
          'es': 1,
          'give': 1,
          'introduction': 1,
          'new': 1,
          'scientist': 1,
          'the': 1,
          'to': 1,
          'webinar': 1,
          'who': 1,
          'will': 1}),
 Counter({'@datacamp': 1,
          '@mbenchi': 1,
          'Hello': 1,
          'com': 1,
          'contact': 1,
          'please': 1,
          'support': 1}),
 Counter({'@CVWickham': 1,
          'Dates': 1,
          'R': 1,
          'This': 1,
          'Times': 1,
          'Working': 1,
          'a': 1,
          'and': 1,
          'by': 1,
          'course': 1,
          'essentials': 1,
          'in': 1,
          'manipulating': 1,
          'of': 1,
          'parsing': 1,
          'teaches': 1,
          'the': 1,
          'with': 1,
          'you': 1}),
 Counter({'@datacamp': 1,
          '@jpls': 1,
          'Hi': 1,
          'John': 1,
          'They': 1,
          'able': 1,
          'be': 1,
          'com': 1,
          'contact': 1,
          'into': 1,
          'look': 1,
          'please': 1,
          'situation': 1,
          'specific': 1,
          'support': 1,
          'to': 1,
          'will': 1,
          'your': 1}),
 Counter({'@datacamp': 1,
          '@shankarSRC': 1,
          'Hi': 1,
          'Shankar': 1,
          'They': 1,
          'able': 1,
          'be': 1,
          'com': 1,
          'contact': 1,
          'into': 1,
          'issue': 1,
          'look': 1,
          'please': 1,
          'specific': 1,
          'support': 1,
          'to': 1,
          'will': 1,
          'your': 1}),
 Counter({'@datacamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          '@ur': 1,
          'Hi': 1,
          'They': 1,
          'Zaid': 1,
          'able': 1,
          'be': 1,
          'com': 1,
          'contact': 1,
          'into': 1,
          'issue': 1,
          'look': 1,
          'please': 1,
          'specific': 1,
          'support': 1,
          'to': 1,
          'will': 1,
          'your': 1,
          'zee': 1}),
 Counter({'#Bayes': 1,
          '#Naive': 1,
          'Bayes': 1,
          'Classification': 1,
          'Learn': 1,
          'Naive': 1,
          'New': 1,
          'Scikit': 1,
          'Tutorial': 1,
          'a': 1,
          'and': 1,
          'build': 1,
          'evaluate': 1,
          'how': 1,
          'learn': 1,
          'to': 1,
          'using': 1}),
 Counter({'#Python': 1,
          '#SciPy': 1,
          'SciPy': 1,
          'This': 1,
          'algebra': 1,
          'basics': 1,
          'cheat': 1,
          'covers': 1,
          'get': 1,
          'in': 1,
          'linear': 1,
          'need': 1,
          'of': 1,
          'sheet': 1,
          'started': 1,
          'that': 1,
          'the': 1,
          'to': 1,
          'you': 1}),
 Counter({'#Python': 1,
          '#machinelearning': 1,
          'Scikit': 1,
          'cheat': 1,
          'learn': 1,
          'sheet': 1,
          'with': 1}),
 Counter({'Bivariate': 1,
          'Distribution': 1,
          'Heatmaps': 1,
          'Learn': 1,
          'R': 1,
          'Tutorial': 1,
          'between': 1,
          'features': 1,
          'h': 1,
          'how': 1,
          'in': 1,
          'relationship': 1,
          'show': 1,
          'the': 1,
          'to': 1,
          'two': 1,
          'visually': 1}),
 Counter({'Data': 1,
          'Demystifying': 1,
          'In': 1,
          'Python': 1,
          'Sci': 1,
          'about': 1,
          'basic': 1,
          'crucial': 1,
          'for': 1,
          'in': 1,
          'learn': 1,
          'required': 1,
          'statistics': 2,
          'the': 1,
          'this': 1,
          'tutorial': 1}),
 Counter({'@aayushraman': 1,
          '@datacamp': 1,
          'Hi': 1,
          'They': 1,
          'able': 1,
          'assist': 1,
          'be': 1,
          'com': 1,
          'contact': 1,
          'issue': 1,
          'please': 1,
          'support': 1,
          'this': 1,
          'to': 1,
          'will': 1,
          'with': 1,
          'you': 1}),
 Counter({'@venturidb': 1,
          'Blog': 1,
          'DataCam': 1,
          'January': 1,
          'Learn': 1,
          'New': 1,
          'Post': 1,
          'Projects': 1,
          'Proposal': 1,
          'Request': 1,
          'Topical': 1,
          'a': 1,
          'become': 1,
          'by': 1,
          'for': 2,
          'how': 1,
          'to': 1}),
 Counter({'#Zip': 1,
          'File': 1,
          'Files': 1,
          'In': 2,
          'New': 1,
          'Python': 1,
          'Tutorial': 1,
          'With': 1,
          'Working': 1,
          'Zip': 1,
          'are': 1,
          'going': 1,
          'how': 1,
          'learn': 1,
          'this': 1,
          'to': 2,
          'tutorial': 1,
          'with': 1,
          'work': 1,
          'you': 1}),
 Counter({'Elastic': 1,
          'In': 1,
          'Lasso': 1,
          'Net': 1,
          'New': 1,
          'Regularization': 1,
          'Ridge': 1,
          'Tutorial': 1,
          'acquainted': 1,
          'and': 1,
          'bias': 1,
          'get': 1,
          'the': 1,
          'this': 1,
          'tutorial': 1,
          'will': 1,
          'with': 1,
          'you': 1}),
 Counter({'@datacamp': 1,
          'Hi': 1,
          'com': 1,
          'contact': 1,
          'nighthawk': 1,
          'please': 1,
          'support': 1}),
 Counter({'#analytics': 1,
          '#datascience': 1,
          '#wintechseries': 1,
          '@DataCamp': 1,
          '@data': 1,
          'I': 1,
          'Mes': 1,
          'RT': 1,
          'We': 1,
          'all': 1,
          'and': 2,
          'at': 1,
          'experts': 1,
          'for': 1,
          'hiring': 1,
          'jen': 1,
          'looking': 1,
          'm': 1,
          're': 1,
          'representing': 1,
          'week': 1}),
 Counter({'Auto': 1,
          'Automated': 1,
          'Keras': 1,
          'Learn': 1,
          'Learning': 1,
          'Machine': 1,
          'New': 1,
          'Tutorial': 1,
          'about': 1,
          'and': 1,
          'automated': 1,
          'be': 1,
          'can': 1,
          'how': 1,
          'it': 1,
          'learning': 1,
          'machine': 1,
          'with': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          'Ep': 1,
          'I': 1,
          'In': 1,
          'Math': 1,
          'RT': 1,
          'Season': 1,
          'Weapons': 1,
          'author': 1,
          'finale': 1,
          'of': 4,
          'our': 1,
          'pod': 1,
          'speak': 1,
          'the': 1,
          'with': 1}),
 Counter({'@datacamp': 1,
          '@itsmevidhya': 1,
          'Hi': 1,
          'Vidhya': 1,
          'com': 1,
          'contact': 1,
          'exists': 1,
          'if': 1,
          'issue': 1,
          'k': 1,
          'please': 1,
          'still': 1,
          'support': 1,
          'the': 1}),
 Counter({'#ML': 1,
          'Get': 1,
          'Introduction': 1,
          'Learning': 2,
          'Machine': 2,
          'New': 1,
          'Python': 1,
          'Tutorial': 1,
          'in': 1,
          'introduced': 1,
          'of': 1,
          'the': 1,
          'to': 2,
          'wit': 1,
          'world': 1}),
 Counter({'@datacamp': 1,
          '@m': 1,
          'Hi': 1,
          'Martin': 1,
          'They': 1,
          'able': 1,
          'be': 1,
          'com': 1,
          'contact': 1,
          'help': 1,
          'in': 1,
          'please': 1,
          's': 1,
          'support': 1,
          'to': 1,
          'will': 1}),
 Counter({'Analytics': 1,
          'BI': 1,
          'Comparison': 1,
          'In': 1,
          'New': 1,
          'Platforms': 1,
          'Tutorial': 1,
          'about': 1,
          'and': 1,
          'different': 1,
          'factors': 1,
          'learn': 1,
          'of': 1,
          'th': 1,
          'this': 1,
          'tutorial': 1,
          'will': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '@hugobowne': 1,
          '@mathbabedotorg': 1,
          'Destruction': 1,
          'Episode': 1,
          'Math': 1,
          'New': 1,
          'Weapons': 1,
          'about': 1,
          'author': 1,
          'of': 2,
          'speaks': 1,
          'the': 1,
          'with': 1}),
 Counter({'@datacamp': 1,
          '@hizoka': 1,
          'Hi': 1,
          'andou': 1,
          'com': 1,
          'contact': 1,
          'please': 1,
          'support': 1}),
 Counter({'#Python': 1,
          'This': 1,
          'analysis': 1,
          'basics': 1,
          'cheat': 1,
          'data': 1,
          'handy': 1,
          'need': 1,
          'one': 1,
          'page': 1,
          'perform': 1,
          'presents': 1,
          'sheet': 1,
          'that': 1,
          'the': 1,
          'to': 1,
          'you': 1}),
 Counter({'Amazon': 1,
          'Cloud': 1,
          'Compute': 1,
          'Discover': 1,
          'EC': 1,
          'Elastic': 1,
          'Services': 1,
          'Web': 1,
          'a': 1,
          'and': 1,
          'basic': 1,
          'can': 1,
          'data': 1,
          'how': 1,
          'sci': 1,
          'set': 1,
          'should': 1,
          'up': 1,
          'use': 1,
          'why': 1,
          'you': 2}),
 Counter({'Carlo': 2,
          'In': 1,
          'Introduction': 1,
          'Methods': 1,
          'Monte': 2,
          'and': 1,
          'ap': 1,
          'its': 1,
          'learn': 1,
          'methodology': 1,
          'reader': 1,
          'the': 2,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'will': 1}),
 Counter({'#PySpark': 1,
          '#Python': 1,
          '#SQL': 1,
          '#Spark': 1,
          'DataFrames': 1,
          'Get': 1,
          'SQL': 1,
          'Working': 1,
          'and': 1,
          'cheat': 1,
          'in': 1,
          'sheet': 1,
          'with': 1,
          'your': 1}),
 Counter({'#Atom': 1,
          '#IDE': 1,
          'Atom': 1,
          'IDEs': 1,
          'In': 1,
          'New': 1,
          'Overview': 1,
          'Tutorial': 1,
          'an': 1,
          'how': 1,
          'importance': 1,
          'learn': 1,
          'll': 1,
          'of': 2,
          'set': 1,
          'the': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'up': 1,
          'you': 1}),
 Counter({'@venturidb': 1,
          'An': 1,
          'DataCamp': 2,
          'Introduction': 1,
          'New': 1,
          'Project': 1,
          'Projects': 1,
          'by': 1,
          'introduction': 1,
          'll': 1,
          'projects': 1,
          'to': 2,
          'walk': 1,
          'we': 1,
          'you': 1}),
 Counter({'Thank': 1,
          'The': 1,
          'and': 2,
          'back': 1,
          'been': 1,
          'currently': 1,
          'everything': 1,
          'for': 1,
          'has': 1,
          'is': 1,
          'issue': 1,
          'patience': 1,
          'resolved': 1,
          'running': 1,
          'up': 1,
          'you': 1,
          'your': 1}),
 Counter({'We': 3,
          'are': 3,
          'aware': 1,
          'back': 1,
          'courses': 1,
          'currently': 1,
          'down': 1,
          'get': 1,
          'hard': 1,
          'our': 1,
          'that': 1,
          'them': 1,
          'to': 1,
          'update': 1,
          'will': 1,
          'working': 2,
          'you': 1}),
 Counter({'@ErinLaBrecq': 1,
          'Are': 1,
          'Fishes': 1,
          'In': 1,
          'New': 1,
          'Project': 1,
          'Where': 1,
          'by': 1,
          'c': 1,
          'data': 1,
          'explore': 1,
          'files': 1,
          'georeferenced': 1,
          'project': 1,
          'the': 1,
          'this': 1,
          'two': 1,
          'will': 1,
          'you': 1}),
 Counter({'#multivariate': 1,
          'Course': 1,
          'Distributions': 1,
          'In': 1,
          'Multivariate': 1,
          'New': 1,
          'Probability': 1,
          'R': 1,
          'about': 1,
          'common': 1,
          'course': 1,
          'in': 1,
          'learn': 1,
          'll': 1,
          'this': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@wesmckinn': 1,
          'Director': 1,
          'Ep': 1,
          'I': 1,
          'In': 1,
          'Labs': 1,
          'RT': 1,
          'Ursa': 1,
          'and': 1,
          'creator': 1,
          'of': 3,
          'pandas': 1,
          'podcast': 1,
          'pr': 1,
          'speak': 1,
          'the': 2,
          'with': 1}),
 Counter({'#AdaBoost': 1,
          'AdaBoost': 1,
          'Classifier': 1,
          'New': 1,
          'Python': 1,
          'Tutorial': 1,
          'Understand': 1,
          'a': 1,
          'algorithm': 1,
          'approach': 1,
          'ensemble': 1,
          'in': 1,
          'of': 1,
          'the': 2,
          'working': 1}),
 Counter({'Art': 1,
          'Between': 1,
          'Deep': 1,
          'Differences': 1,
          'In': 1,
          'Learning': 2,
          'Machine': 1,
          'New': 1,
          'Tutorial': 1,
          'an': 1,
          'get': 1,
          'll': 1,
          'of': 1,
          'overview': 1,
          'this': 1,
          'tutorial': 1,
          'you': 1}),
 Counter({'#pandas': 1,
          '@hugobowne': 1,
          '@wesmckinn': 1,
          'DataFramed': 1,
          'Director': 1,
          'Episode': 1,
          'Labs': 1,
          'New': 1,
          'Ursa': 1,
          'and': 1,
          'creator': 1,
          'of': 2,
          'project': 1,
          'speaks': 1,
          'the': 1,
          'with': 1}),
 Counter({'Data': 1,
          'In': 1,
          'Processing': 1,
          'R': 1,
          'Scalable': 1,
          'analyzing': 1,
          'course': 1,
          'data': 1,
          'directly': 1,
          'exploring': 1,
          'for': 1,
          'fro': 1,
          'in': 1,
          'learn': 1,
          'processing': 1,
          'this': 1,
          'tools': 1}),
 Counter({'If': 1,
          'a': 1,
          'and': 1,
          'approach': 1,
          'data': 2,
          'fresh': 1,
          'interact': 1,
          'interactive': 1,
          'let': 1,
          'story': 1,
          'take': 1,
          'telling': 1,
          'to': 2,
          'users': 1,
          'want': 1,
          'with': 1,
          'you': 1,
          'your': 2}),
 Counter({'A': 1,
          'Apache': 1,
          'Beginner': 1,
          'Guide': 1,
          'Python': 2,
          'Spark': 2,
          'based': 1,
          'beginner': 1,
          'in': 2,
          'on': 1,
          'popular': 1,
          'questions': 1,
          's': 2,
          'su': 1,
          'to': 1,
          'tutorial': 1}),
 Counter({'In': 1,
          'Shiny': 1,
          'and': 1,
          'apps': 1,
          'cases': 1,
          'common': 1,
          'course': 1,
          'developing': 1,
          'different': 1,
          'experience': 1,
          'for': 1,
          'fun': 1,
          'get': 1,
          'll': 1,
          'realistic': 1,
          'such': 1,
          'this': 1,
          'use': 1,
          'you': 1}),
 Counter({'Apache': 2,
          'ML': 1,
          'PySpark': 1,
          'Spark': 2,
          'This': 1,
          'Tutorial': 1,
          'analysis': 1,
          'big': 1,
          'data': 1,
          'introduces': 1,
          'processing': 1,
          'to': 1,
          'tutorial': 1,
          'with': 1,
          'you': 1}),
 Counter({'@LoreDirick': 1,
          'Finance': 1,
          'In': 1,
          'Introduction': 1,
          'R': 2,
          'by': 1,
          'essential': 1,
          'finance': 1,
          'for': 1,
          'introduction': 1,
          'learn': 1,
          'oriented': 1,
          'this': 1,
          'to': 2,
          'will': 1,
          'you': 1}),
 Counter({'#DataVisualization': 1,
          '@ACSundermann': 1,
          'RT': 1,
          'So': 1,
          'and': 1,
          'communicating': 1,
          'data': 1,
          'findings': 1,
          'for': 2,
          'geeked': 1,
          'is': 1,
          'key': 1,
          'others': 1,
          'own': 1,
          'ta': 1,
          'to': 1,
          'understanding': 1,
          'with': 1,
          'your': 1}),
 Counter({'#analysis': 1,
          '#sentiment': 1,
          'Analysis': 1,
          'Learn': 1,
          'New': 1,
          'Python': 1,
          'Sentiment': 1,
          'Simplifying': 1,
          'Tutorial': 1,
          'a': 1,
          'and': 1,
          'basics': 1,
          'build': 1,
          'how': 1,
          'in': 1,
          'of': 1,
          'the': 1,
          'to': 1}),
 Counter({'Alfred': 1,
          'Analyzing': 1,
          'Clinical': 1,
          'Course': 1,
          'Designing': 1,
          'New': 1,
          'R': 1,
          'Tamuno': 1,
          'Trials': 1,
          'You': 1,
          'an': 1,
          'and': 1,
          'by': 1,
          'gain': 1,
          'important': 1,
          'in': 1,
          'll': 1,
          'of': 1,
          'overview': 1,
          'the': 1}),
 Counter({'@dirtymodelling': 1,
          '@nj': 1,
          'Also': 1,
          'Hi': 1,
          'Sarah': 1,
          'We': 1,
          'are': 1,
          'for': 2,
          'future': 1,
          'into': 1,
          'it': 1,
          'know': 1,
          'letting': 1,
          'looking': 1,
          'now': 1,
          'thank': 1,
          'tierney': 1,
          'us': 1,
          'you': 1}),
 Counter({'#purrr': 1,
          '@RallidaeRule': 1,
          'Course': 1,
          'Foundations': 1,
          'Functional': 1,
          'Learn': 1,
          'New': 1,
          'Programming': 1,
          'by': 1,
          'easily': 1,
          'extract': 1,
          'of': 1,
          'summarize': 1,
          'to': 1,
          'with': 1}),
 Counter({'#naniar': 1,
          '#tidyverse': 1,
          '@nj': 1,
          'Course': 1,
          'Data': 1,
          'Dealing': 1,
          'Learn': 1,
          'Missing': 1,
          'New': 1,
          'R': 2,
          'With': 1,
          'and': 1,
          'by': 1,
          'how': 1,
          'in': 1,
          'pack': 1,
          'the': 1,
          'tierney': 1,
          'to': 1,
          'tools': 1,
          'use': 1}),
 Counter({'@drivendataorg': 1,
          '@hugobowne': 1,
          '@pjbull': 1,
          'Data': 1,
          'Driven': 1,
          'Listen': 1,
          'RT': 1,
          'a': 1,
          'about': 1,
          'and': 1,
          'as': 1,
          'co': 1,
          'data': 1,
          'for': 1,
          'founder': 1,
          'good': 1,
          'of': 1,
          'our': 1,
          'own': 1,
          'scientist': 1,
          'social': 1,
          't': 1,
          'talks': 1,
          'with': 1}),
 Counter({'#Nashville': 1,
          '#OpenData': 1,
          '#data': 1,
          '#geospatial': 1,
          '@MaryLvV': 1,
          'Check': 1,
          'DataCamp': 1,
          'I': 1,
          'RT': 1,
          'course': 1,
          'from': 1,
          'get': 1,
          'how': 1,
          'in': 1,
          'insight': 1,
          'it': 1,
          'll': 1,
          'out': 1,
          'show': 1,
          'this': 1,
          'to': 1,
          'using': 1,
          'you': 1,
          'your': 1}),
 Counter({'@xZorex': 1,
          'Thank': 1,
          'We': 1,
          'attention': 1,
          'bringing': 1,
          'for': 1,
          'into': 1,
          'it': 1,
          'look': 1,
          'our': 1,
          'this': 1,
          'to': 1,
          'will': 1,
          'you': 1}),
 Counter({'@BigData': 1,
          '@maartenlambert': 1,
          '@mmughal': 1,
          'All': 1,
          'Community': 1,
          'Here': 1,
          'LDN': 1,
          'are': 1,
          'cheat': 1,
          'is': 1,
          'link': 1,
          'located': 1,
          'of': 1,
          'on': 1,
          'our': 2,
          'sheets': 1,
          'the': 1}),
 Counter({'@JonathanEStarr': 1,
          'Hi': 1,
          'Jonathan': 1,
          'are': 1,
          'available': 1,
          'bottom': 1,
          'course': 1,
          'datasets': 1,
          'download': 1,
          'for': 1,
          'of': 1,
          'on': 1,
          'page': 1,
          'right': 1,
          'the': 3,
          'to': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@wesmckinn': 1,
          'I': 1,
          'RT': 1,
          'a': 2,
          'about': 1,
          'am': 1,
          'conversation': 1,
          'editing': 1,
          'ep': 1,
          'having': 1,
          'helluva': 1,
          'next': 1,
          'of': 1,
          'podcast': 1,
          's': 1,
          'the': 1,
          'time': 1,
          'w': 1,
          'week': 1}),
 Counter({'@MaryLvV': 1,
          'Course': 1,
          'Data': 1,
          'Geospatial': 1,
          'In': 1,
          'New': 1,
          'Python': 1,
          'Visualizing': 1,
          'attractive': 1,
          'by': 1,
          'course': 1,
          'in': 1,
          'learn': 1,
          'll': 1,
          'make': 1,
          'this': 1,
          'to': 1,
          'you': 1}),
 Counter({'@BigData': 1,
          '@EnterEnergy': 1,
          '@maartenlambert': 1,
          'All': 1,
          'Community': 1,
          'Here': 1,
          'LDN': 1,
          'are': 1,
          'cheat': 1,
          'is': 1,
          'link': 1,
          'located': 1,
          'of': 1,
          'on': 1,
          'our': 2,
          'sheets': 1,
          'the': 1}),
 Counter({'@BigData': 1,
          '@maartenlambert': 1,
          'Come': 1,
          'DataCamp': 1,
          'LDN': 1,
          'RT': 1,
          'We': 1,
          'also': 1,
          'and': 1,
          'at': 1,
          'b': 1,
          'collect': 1,
          'everyone': 1,
          'for': 1,
          'free': 1,
          'handout': 1,
          'our': 1,
          'passing': 1,
          'stand': 1,
          'swag': 1,
          'today': 1,
          'trials': 1,
          'your': 1}),
 Counter({'#finance': 1,
          '@emilyriederer': 1,
          'Analytics': 1,
          'Course': 1,
          'Financial': 1,
          'New': 1,
          'R': 1,
          'This': 1,
          'an': 1,
          'by': 1,
          'cash': 1,
          'course': 1,
          'in': 1,
          'intro': 1,
          'is': 1,
          'of': 1,
          'the': 1,
          'to': 1,
          'where': 1,
          'world': 1}),
 Counter({'#DataFramed': 1,
          '@AngeBassa': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@iRobot': 1,
          'Data': 1,
          'Director': 1,
          'Episode': 1,
          'I': 1,
          'In': 1,
          'RT': 1,
          'Science': 1,
          'a': 1,
          'about': 1,
          'at': 1,
          'managing': 1,
          'of': 2,
          'pod': 1,
          'speak': 1,
          'with': 1}),
 Counter({'@ashutoshkaushal': 1,
          'Here': 1,
          'Hey': 1,
          'Introduction': 1,
          'R': 1,
          'and': 1,
          'chapter': 1,
          'course': 2,
          'entire': 1,
          'every': 1,
          'first': 1,
          'free': 1,
          'is': 2,
          'our': 1,
          'so': 1,
          'the': 1,
          'to': 2}),
 Counter({'Cluster': 1,
          'This': 1,
          'analysis': 1,
          'characteristics': 1,
          'course': 1,
          'find': 1,
          'groups': 1,
          'introd': 1,
          'is': 1,
          'observations': 1,
          'of': 1,
          'share': 1,
          'similar': 1,
          'that': 1,
          'to': 1,
          'used': 1,
          'will': 1}),
 Counter({'@Rbloggers': 1,
          'Angela': 1,
          'Bassa': 1,
          'RT': 1,
          'and': 1,
          'data': 1,
          'discusses': 1,
          'managing': 1,
          'more': 1,
          'much': 1,
          'science': 1,
          'teams': 1}),
 Counter({'@AngeBassa': 1,
          '@hugobowne': 1,
          '@iRobot': 1,
          'Data': 1,
          'DataFramed': 1,
          'Director': 1,
          'Episode': 1,
          'New': 1,
          'Science': 1,
          'about': 1,
          'at': 1,
          'data': 1,
          'leading': 1,
          'of': 1,
          'speaks': 1,
          'with': 1}),
 Counter({'Lemmatization': 2,
          'Python': 1,
          'Stemming': 2,
          'Tex': 1,
          'This': 1,
          'and': 1,
          'covers': 1,
          'in': 2,
          'introduction': 1,
          'the': 1,
          'to': 1,
          'tutorial': 1,
          'used': 1}),
 Counter({'@CVWickham': 1,
          'Dates': 1,
          'R': 1,
          'This': 1,
          'Times': 1,
          'Working': 1,
          'a': 1,
          'and': 1,
          'by': 1,
          'course': 1,
          'essentials': 1,
          'in': 1,
          'manipulating': 1,
          'of': 1,
          'parsing': 1,
          'teaches': 1,
          'the': 1,
          'with': 1,
          'you': 1}),
 Counter({'#NetworkX': 1,
          'Graph': 1,
          'NetworkX': 1,
          'Optimization': 1,
          'Python': 1,
          'This': 1,
          'do': 1,
          'graph': 1,
          'how': 1,
          'in': 2,
          'optimization': 1,
          'show': 1,
          'to': 1,
          'tutorial': 1,
          'will': 1,
          'with': 1,
          'you': 1}),
 Counter({'@minebocek': 1,
          'Applications': 1,
          'Building': 1,
          'R': 2,
          'Shiny': 2,
          'This': 1,
          'Web': 1,
          'by': 1,
          'course': 1,
          'devel': 1,
          'from': 1,
          'in': 1,
          'programmer': 1,
          'take': 1,
          'to': 1,
          'will': 1,
          'with': 1,
          'you': 1}),
 Counter({'Data': 1,
          'Highcharter': 2,
          'Learn': 1,
          'R': 1,
          'Visualization': 1,
          'a': 2,
          'buz': 1,
          'create': 1,
          'creates': 1,
          'how': 1,
          'in': 1,
          'that': 1,
          'to': 2,
          'use': 1,
          'visualization': 1,
          'with': 1}),
 Counter({'@hankroark': 1,
          'Learning': 1,
          'R': 1,
          'This': 1,
          'Unsupervised': 1,
          'a': 1,
          'and': 1,
          'basic': 1,
          'by': 1,
          'clustering': 1,
          'course': 1,
          'dimensionalit': 1,
          'in': 1,
          'introduction': 1,
          'provides': 1,
          'to': 1}),
 Counter({'@teeniedeenie': 1,
          'Finance': 1,
          'Intro': 1,
          'Python': 1,
          'Take': 1,
          'The': 1,
          'adoptin': 1,
          'by': 1,
          'course': 1,
          'financial': 1,
          'for': 1,
          'increasingly': 1,
          'industry': 1,
          'is': 1,
          'our': 1,
          'taught': 1,
          'to': 1}),
 Counter({'#DataFramed': 1,
          '@AngeBassa': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@iRobot': 1,
          'Data': 1,
          'Director': 1,
          'Get': 1,
          'RT': 1,
          'Science': 1,
          'a': 2,
          'conversation': 1,
          'ep': 1,
          'for': 1,
          'next': 1,
          'of': 2,
          'pod': 1,
          'ready': 1,
          's': 1,
          'w': 1,
          'week': 1}),
 Counter({'@datacamp': 1,
          '@goonereyang': 1,
          'Hi': 1,
          'a': 1,
          'attention': 1,
          'bringing': 1,
          'com': 1,
          'contact': 1,
          'could': 1,
          'for': 1,
          'our': 1,
          'please': 1,
          'support': 1,
          'thank': 1,
          'this': 1,
          'to': 1,
          'with': 1,
          'you': 2}),
 Counter({'#rstatsdc': 1,
          '@datacamp': 1,
          '@robinso': 1,
          '@rstatsnyc': 1,
          'A': 1,
          'B': 1,
          'Emily': 1,
          'RT': 1,
          'Robinson': 1,
          'discover': 1,
          'from': 1,
          'how': 1,
          'insights': 1,
          'meaningful': 1,
          'set': 1,
          'testing': 1,
          'through': 1,
          'to': 2,
          'up': 1,
          'us': 1,
          'walks': 1}),
 Counter({'Carlo': 2,
          'In': 1,
          'Introduction': 1,
          'Methods': 1,
          'Monte': 2,
          'New': 1,
          'Tutorial': 1,
          'learn': 1,
          'methodol': 1,
          'reader': 1,
          'the': 2,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'will': 1}),
 Counter({'#Python': 1,
          '@sarah': 1,
          'Learning': 1,
          'Machine': 1,
          'Preprocessing': 1,
          'Python': 1,
          'This': 1,
          'and': 1,
          'basics': 1,
          'by': 1,
          'course': 1,
          'covers': 1,
          'for': 1,
          'guido': 1,
          'how': 1,
          'in': 1,
          'of': 1,
          'the': 1,
          'when': 1}),
 Counter({'@HEX': 1,
          'A': 1,
          'Approach': 1,
          'C': 1,
          'Course': 1,
          'Network': 1,
          'New': 1,
          'R': 1,
          'Science': 1,
          'This': 1,
          'Tidy': 1,
          'analysis': 1,
          'by': 1,
          'course': 1,
          'demonstrate': 1,
          'in': 1,
          'network': 1,
          'using': 1,
          'will': 1,
          'x': 1}),
 Counter({'@DataCamp': 1,
          '@HillGreenLerman': 1,
          '@mona': 1,
          'How': 1,
          'RT': 1,
          'Thanks': 1,
          'at': 1,
          'coordinating': 1,
          'create': 1,
          'data': 1,
          'for': 1,
          'here': 1,
          'khm': 1,
          'sets': 1,
          'simulated': 1,
          'this': 1,
          'to': 1,
          'we': 1}),
 Counter({'#datascience': 1,
          '#nerds': 1,
          '@DataCamp': 1,
          '@HillGreenLerman': 1,
          '@mona': 1,
          'Data': 1,
          'RT': 1,
          'Science': 1,
          'Shows': 1,
          'TV': 1,
          'The': 1,
          'are': 1,
          'at': 1,
          'coming': 1,
          'folks': 1,
          'fun': 1,
          'having': 1,
          'https': 1,
          'khm': 1,
          'themed': 1,
          'up': 1,
          'with': 1}),
 Counter({'@hugobowne': 1,
          '@pjbull': 1,
          'Glad': 1,
          'RT': 1,
          'a': 1,
          'always': 1,
          'and': 1,
          'delight': 1,
          'engagement': 1,
          'given': 1,
          'his': 1,
          'insightful': 1,
          'it': 1,
          'of': 1,
          'one': 1,
          'our': 1,
          'questions': 1,
          's': 1,
          'such': 1,
          'talk': 1,
          'thoughtful': 1,
          'to': 1,
          'with': 1}),
 Counter({'#Spreadsheets': 1,
          'Course': 1,
          'Frank': 1,
          'Learn': 1,
          'New': 1,
          'Pivot': 1,
          'Sumanski': 1,
          'Tables': 1,
          'as': 1,
          'by': 1,
          'fil': 1,
          'sorting': 1,
          'subtotaling': 1,
          'such': 1,
          'techniques': 1,
          'with': 1}),
 Counter({'#Spreadsheets': 1,
          '@richierocks': 1,
          'Course': 1,
          'Data': 1,
          'Google': 1,
          'Intermediate': 1,
          'New': 1,
          'Science': 1,
          'Sheets': 1,
          'This': 1,
          'by': 1,
          'course': 1,
          'expand': 1,
          'for': 1,
          'will': 1,
          'your': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@drivendataorg': 1,
          '@hugobowne': 1,
          '@pjbull': 1,
          'Episode': 1,
          'I': 1,
          'In': 1,
          'RT': 1,
          'a': 1,
          'about': 1,
          'centered': 1,
          'human': 1,
          'importance': 1,
          'of': 3,
          'pod': 1,
          'speak': 1,
          'the': 1,
          'with': 1}),
 Counter({'Computing': 1,
          'Dask': 2,
          'Parallel': 1,
          'This': 1,
          'a': 1,
          'ana': 1,
          'computing': 1,
          'course': 1,
          'flexible': 1,
          'for': 1,
          'introduce': 1,
          'library': 1,
          'parallel': 1,
          'to': 1,
          'will': 1,
          'with': 1,
          'you': 1}),
 Counter({'#Election': 1,
          '#ElectionDay': 1,
          '#Polling': 1,
          'Analyzing': 1,
          'Data': 1,
          'In': 1,
          'R': 1,
          'US': 1,
          'and': 1,
          'by': 1,
          'course': 1,
          'honor': 1,
          'in': 2,
          'new': 1,
          'of': 1,
          'our': 1,
          'take': 1,
          'the': 1}),
 Counter({'@drivendataorg': 1, 'RT': 1}),
 Counter({'#DataFramed': 1,
          '@hugobowne': 1,
          '@pjbull': 1,
          'Episode': 1,
          'New': 1,
          'a': 1,
          'and': 1,
          'co': 1,
          'data': 1,
          'for': 1,
          'founder': 1,
          'good': 1,
          'of': 1,
          'scientist': 1,
          'social': 1,
          'speaks': 1,
          'with': 1}),
 Counter({'@gelliottmorris': 1,
          'Analyzing': 1,
          'Data': 1,
          'Election': 1,
          'Have': 1,
          'In': 1,
          'Polling': 1,
          'R': 1,
          'a': 1,
          'and': 1,
          'by': 1,
          'course': 2,
          'in': 1,
          'll': 1,
          'new': 1,
          'our': 1,
          'taken': 1,
          'this': 1,
          'you': 2}),
 Counter({'@datacamp': 1,
          '@tbalci': 1,
          'Please': 1,
          'com': 1,
          'contact': 1,
          'support': 1}),
 Counter({'In': 1,
          'Time': 1,
          'all': 1,
          'are': 1,
          'around': 1,
          'course': 1,
          'data': 1,
          'ev': 1,
          'financial': 1,
          'frequency': 1,
          'from': 1,
          'high': 1,
          'learn': 1,
          'logs': 1,
          'series': 1,
          'server': 1,
          'this': 1,
          'to': 1,
          'us': 1,
          'will': 1,
          'you': 1}),
 Counter({'Apache': 2,
          'ML': 1,
          'PySpark': 1,
          'Spark': 2,
          'This': 1,
          'Tutorial': 1,
          'analysis': 1,
          'big': 1,
          'data': 1,
          'introduces': 1,
          'processing': 1,
          'to': 1,
          'tutorial': 1,
          'with': 1,
          'you': 1}),
 Counter({'Many': 1,
          'a': 1,
          'are': 1,
          'as': 1,
          'day': 2,
          'in': 2,
          'intervals': 1,
          'lives': 1,
          'measured': 1,
          'movement': 1,
          'of': 1,
          'our': 1,
          'over': 1,
          'peri': 1,
          'phenomena': 1,
          'prices': 1,
          'stock': 1,
          'such': 1,
          'the': 1,
          'to': 1}),
 Counter({'A': 1,
          'Apache': 1,
          'Beginner': 1,
          'Guide': 1,
          'Python': 2,
          'Spark': 2,
          'based': 1,
          'beginner': 1,
          'in': 2,
          'on': 1,
          'popular': 1,
          'questions': 1,
          's': 2,
          'su': 1,
          'to': 1,
          'tutorial': 1}),
 Counter({'@LoreDirick': 1,
          'Finance': 1,
          'In': 1,
          'Introduction': 1,
          'R': 2,
          'by': 1,
          'essential': 1,
          'finance': 1,
          'for': 1,
          'introduction': 1,
          'learn': 1,
          'oriented': 1,
          'this': 1,
          'to': 2,
          'will': 1,
          'you': 1}),
 Counter({'@datacamp': 1,
          '@masadowski': 1,
          'Hi': 1,
          'Mark': 1,
          'They': 1,
          'able': 1,
          'assist': 1,
          'be': 1,
          'better': 1,
          'com': 1,
          'contact': 1,
          'please': 1,
          'support': 1,
          'to': 1,
          'will': 1,
          'you': 1}),
 Counter({'#JSON': 1,
          '#Python': 1,
          'Data': 1,
          'In': 1,
          'JSON': 1,
          'New': 1,
          'Python': 1,
          'Tutorial': 1,
          'about': 1,
          'different': 1,
          'in': 2,
          'learn': 1,
          'll': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'use': 1,
          'ways': 1,
          'you': 1}),
 Counter({'Essentials': 1,
          'Learn': 1,
          'Linear': 1,
          'New': 1,
          'Python': 1,
          'Regression': 1,
          'Tutorial': 1,
          'a': 2,
          'and': 1,
          'formulates': 1,
          'how': 1,
          'in': 1,
          'of': 1,
          'problem': 1,
          'regression': 1,
          'what': 1}),
 Counter({'#Rstats': 1,
          '@gelliottmorris': 1,
          'Hello': 1,
          'RT': 1,
          'Today': 1,
          'an': 1,
          'analyses': 1,
          'course': 1,
          'data': 1,
          'day': 1,
          'exciting': 1,
          'for': 1,
          'is': 1,
          'launch': 1,
          'my': 1,
          'of': 1,
          'officially': 1,
          'science': 1,
          'teaching': 1,
          'we': 1,
          'with': 1}),
 Counter({'@Rbloggers': 1,
          'Analyzing': 1,
          'Course': 1,
          'Data': 1,
          'Election': 1,
          'New': 1,
          'Polling': 1,
          'R': 1,
          'RT': 1,
          'and': 1,
          'in': 1}),
 Counter({'@DannyProl': 1,
          '@gary': 1,
          '@gelliottmorris': 1,
          'Analyzing': 1,
          'Data': 1,
          'Election': 1,
          'Here': 1,
          'Polling': 1,
          'R': 1,
          'and': 1,
          'in': 1,
          'is': 1,
          'link': 1,
          'the': 1,
          'thomas': 1}),
 Counter({'@DannyProl': 1,
          '@DataCamp': 1,
          '@gelliottmorris': 1,
          'He': 1,
          'Just': 1,
          'RT': 1,
          'amazing': 1,
          'an': 1,
          'course': 1,
          'courses': 1,
          'do': 1,
          'finished': 1,
          'he': 1,
          'hope': 1,
          'is': 1,
          'more': 1,
          'on': 1,
          'professor': 1,
          'will': 1}),
 Counter({'#Election': 1,
          '#Polling': 1,
          '@gelliottmorris': 1,
          'Analyzing': 1,
          'Course': 1,
          'Data': 1,
          'In': 1,
          'New': 1,
          'and': 1,
          'by': 1,
          'course': 1,
          'how': 1,
          'learn': 1,
          'this': 1,
          'to': 1,
          'visualiz': 1,
          'wrangle': 1}),
 Counter({'#Python': 1,
          '@rabaath': 1,
          'A': 1,
          'History': 1,
          'In': 1,
          'New': 1,
          'Nobel': 1,
          'Prize': 1,
          'Project': 1,
          'Visual': 1,
          'Winners': 1,
          'by': 1,
          'explore': 1,
          'get': 1,
          'of': 1,
          'pat': 1,
          'project': 1,
          'this': 1,
          'to': 1,
          'you': 1}),
 Counter({'@Rbloggers': 1,
          'AI': 1,
          'Arnaub': 1,
          'Chatterjee': 1,
          'ML': 1,
          'RT': 1,
          'and': 1,
          'artificial': 1,
          'discusses': 1,
          'in': 1,
          'intelligence': 1,
          'learning': 1,
          'machine': 1}),
 Counter({'#DataAnalytics': 1,
          '#healthcare': 1,
          '@DataCamp': 1,
          '@ayanalytics': 1,
          'Check': 1,
          'I': 1,
          'RT': 1,
          'Want': 1,
          'about': 1,
          'by': 1,
          'data': 1,
          'designed': 1,
          'for': 1,
          'learn': 1,
          'out': 1,
          'project': 1,
          'real': 1,
          'step': 1,
          'the': 1,
          'to': 1,
          'with': 2}),
 Counter({'#DataFramed': 1,
          '@AK': 1,
          '@DataCamp': 1,
          '@McKAnalytics': 1,
          '@hugobowne': 1,
          'Chatterjee': 1,
          'Episode': 1,
          'I': 1,
          'In': 1,
          'RT': 1,
          'a': 1,
          'abo': 1,
          'as': 1,
          'cuts': 1,
          'he': 1,
          'hype': 1,
          'of': 2,
          'pod': 1,
          'speaks': 1,
          'the': 1,
          'through': 1,
          'with': 1}),
 Counter({'@ayanalytics': 1,
          'Heart': 1,
          'In': 1,
          'Is': 1,
          'New': 1,
          'Project': 1,
          'R': 1,
          'Rate': 1,
          'Telling': 1,
          'What': 1,
          'You': 1,
          'Your': 1,
          'by': 1,
          'examine': 1,
          'project': 1,
          'relations': 1,
          'the': 1,
          'this': 1,
          'will': 1,
          'you': 1}),
 Counter({'@CrackedEggman': 1,
          'Course': 1,
          'Learning': 1,
          'Machine': 1,
          'New': 1,
          'This': 1,
          'Tidyverse': 1,
          'by': 1,
          'course': 1,
          'i': 1,
          'in': 1,
          'leverage': 1,
          'teach': 1,
          'the': 2,
          'to': 1,
          'tools': 1,
          'will': 1,
          'you': 1}),
 Counter({'PEP': 1,
          'Python': 1,
          'With': 1,
          'beginner': 1,
          'can': 1,
          'explore': 1,
          'formatting': 1,
          'guide': 1,
          'll': 1,
          's': 1,
          'so': 1,
          'start': 2,
          'style': 1,
          'that': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'you': 2}),
 Counter({'#DataFramed': 1,
          '#analytics': 1,
          '@AshleyLucchese': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          'One': 1,
          'RT': 1,
          'about': 1,
          'cutting': 1,
          'experts': 1,
          'for': 1,
          'of': 1,
          'our': 1,
          'podcast': 1,
          'recently': 1,
          'spoke': 1,
          'the': 1,
          'thro': 1,
          'with': 1}),
 Counter({'@AllenDowney': 1,
          '@koehrsen': 1,
          'DataCamp': 1,
          'RT': 1,
          'Thoroughly': 1,
          'about': 2,
          'and': 1,
          'enjoyed': 1,
          'how': 1,
          'in': 1,
          'model': 1,
          'podcast': 1,
          'real': 1,
          'talks': 1,
          'think': 1,
          'this': 1,
          'to': 1,
          'uncertainty': 1,
          'will': 1,
          'worl': 1}),
 Counter({'#python': 1,
          '#rstats': 1,
          '#spreadsheets': 1,
          '#sql': 1,
          '@DataCamp': 1,
          '@old': 1,
          'Curious': 1,
          'RT': 1,
          'We': 1,
          'about': 1,
          'build': 1,
          'chester': 1,
          'content': 1,
          'for': 1,
          'it': 1,
          'man': 1,
          'or': 1,
          'premium': 1,
          'rev': 1,
          'takes': 1,
          'to': 1,
          've': 1,
          'what': 1}),
 Counter({'#MongoDB': 1,
          'In': 1,
          'Introduction': 1,
          'MongoDB': 1,
          'New': 1,
          'Python': 1,
          'Tutorial': 1,
          'and': 1,
          'how': 1,
          'integrate': 1,
          'learn': 1,
          'll': 1,
          'this': 1,
          'to': 2,
          'tutorial': 1,
          'with': 1,
          'you': 2}),
 Counter({'#AI': 1,
          '#DataFramed': 1,
          '@DataCamp': 1,
          '@DigitalMcKinsey': 1,
          'Check': 1,
          'RT': 1,
          'and': 1,
          'cut': 1,
          'hype': 1,
          'in': 1,
          'latest': 1,
          'learning': 1,
          'machine': 1,
          'on': 1,
          'out': 1,
          'podcast': 1,
          'the': 3,
          'through': 1,
          'we': 1,
          'where': 1}),
 Counter({'@AK': 1,
          '@McKAnalytics': 1,
          '@hugobowne': 1,
          'Chatterjee': 1,
          'DataFramed': 1,
          'Episode': 1,
          'New': 1,
          'cutting': 1,
          'discuss': 1,
          'hype': 1,
          'of': 1,
          'speaks': 1,
          'the': 1,
          'through': 1,
          'to': 1,
          'with': 1}),
 Counter({'Datasets': 1,
          'In': 1,
          'Merging': 1,
          'New': 1,
          'R': 2,
          'Tutorial': 1,
          'datasets': 1,
          'in': 2,
          'join': 1,
          'learn': 1,
          'll': 1,
          'multiple': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1,
          'you': 1}),
 Counter({'Data': 1,
          'Highcharter': 2,
          'Learn': 1,
          'R': 1,
          'Visualization': 1,
          'a': 2,
          'buz': 1,
          'create': 1,
          'creates': 1,
          'how': 1,
          'in': 1,
          'that': 1,
          'to': 2,
          'use': 1,
          'visualization': 1,
          'with': 1}),
 Counter({'@hankroark': 1,
          'Learning': 1,
          'R': 1,
          'This': 1,
          'Unsupervised': 1,
          'a': 1,
          'and': 1,
          'basic': 1,
          'by': 1,
          'clustering': 1,
          'course': 1,
          'dimensionalit': 1,
          'in': 1,
          'introduction': 1,
          'provides': 1,
          'to': 1}),
 Counter({'Graph': 1,
          'NetworkX': 2,
          'Optimization': 1,
          'Py': 1,
          'Python': 1,
          'This': 1,
          'do': 1,
          'graph': 1,
          'how': 1,
          'in': 2,
          'optimization': 1,
          'show': 1,
          'to': 1,
          'tutorial': 1,
          'will': 1,
          'with': 1,
          'you': 1}),
 Counter({'@minebocek': 1,
          'Applications': 1,
          'Building': 1,
          'R': 2,
          'Shiny': 2,
          'This': 1,
          'Web': 1,
          'by': 1,
          'course': 1,
          'devel': 1,
          'from': 1,
          'in': 1,
          'programmer': 1,
          'take': 1,
          'to': 1,
          'will': 1,
          'with': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '@AK': 1,
          '@DataCamp': 1,
          '@McKAnalytics': 1,
          '@hugobowne': 1,
          'Chatterjee': 1,
          'Launching': 1,
          'RT': 1,
          'a': 1,
          'an': 1,
          'conversation': 1,
          'insider': 1,
          'of': 1,
          'on': 1,
          'podcast': 1,
          'the': 1,
          'tomo': 1,
          'w': 1,
          'wonderful': 1}),
 Counter({'Lemmatization': 2,
          'Python': 1,
          'Stemming': 2,
          'Tex': 1,
          'This': 1,
          'and': 1,
          'covers': 1,
          'in': 2,
          'introduction': 1,
          'the': 1,
          'to': 1,
          'tutorial': 1,
          'used': 1}),
 Counter({'@CVWickham': 1,
          'Dates': 1,
          'R': 1,
          'This': 1,
          'Times': 1,
          'Working': 1,
          'a': 1,
          'and': 1,
          'by': 1,
          'course': 1,
          'essentials': 1,
          'in': 1,
          'manipulating': 1,
          'of': 1,
          'parsing': 1,
          'teaches': 1,
          'the': 1,
          'with': 1,
          'you': 1}),
 Counter({'#noreastr': 1,
          '@DataCamp': 1,
          '@kaelen': 1,
          '@robinson': 1,
          'A': 1,
          'B': 1,
          'RT': 1,
          'about': 1,
          'an': 1,
          'at': 2,
          'best': 1,
          'building': 1,
          'es': 1,
          'https': 1,
          'in': 1,
          'ing': 1,
          'lol': 1,
          'medeiros': 1,
          'out': 1,
          's': 1,
          'system': 1,
          'talk': 1,
          'testing': 1,
          'the': 1,
          'way': 1}),
 Counter({'#noreastr': 1,
          '@richierocks': 1,
          '@robinson': 1,
          'RT': 1,
          'a': 2,
          'and': 1,
          'at': 1,
          'col': 1,
          'column': 1,
          'contain': 1,
          'es': 1,
          'filter': 1,
          'for': 1,
          'great': 1,
          'have': 1,
          'if': 1,
          'list': 1,
          'ones': 1,
          'shows': 1,
          'that': 1,
          'to': 1,
          'trick': 1,
          'want': 1,
          'you': 1}),
 Counter({'In': 1,
          'Introduction': 1,
          'Learning': 1,
          'Machine': 1,
          'a': 1,
          'broad': 1,
          'common': 1,
          'course': 1,
          'discipline': 1,
          'get': 1,
          'll': 1,
          'most': 1,
          'of': 1,
          'overview': 1,
          's': 1,
          'techn': 1,
          'the': 1,
          'this': 1,
          'to': 1,
          'you': 1}),
 Counter({'@mc': 1,
          'XP': 1,
          'a': 1,
          'alila': 1,
          'are': 1,
          'points': 1,
          'progress': 1,
          'to': 1,
          'track': 1,
          'way': 1,
          'your': 1}),
 Counter({'@tymwol': 1,
          'Thank': 1,
          'We': 1,
          'brohrer': 1,
          'for': 1,
          'have': 1,
          'out': 1,
          'pointing': 1,
          'source': 1,
          'that': 1,
          'the': 1,
          'updated': 1,
          'you': 1}),
 Counter({'@mc': 1,
          'Hi': 1,
          'It': 1,
          'alila': 1,
          'and': 1,
          'answer': 1,
          'can': 1,
          'click': 1,
          'complet': 1,
          'credit': 1,
          'for': 1,
          'give': 1,
          'hints': 1,
          'on': 1,
          'run': 1,
          'script': 1,
          'show': 1,
          'the': 2,
          'then': 1,
          'will': 1,
          'you': 2}),
 Counter({'@OleksiyAnokhin': 1,
          'Thank': 1,
          'We': 1,
          'a': 1,
          'are': 1,
          'feedback': 1,
          'for': 1,
          'good': 1,
          'it': 1,
          'on': 1,
          'related': 1,
          's': 1,
          'something': 1,
          'suggestion': 1,
          'the': 1,
          'this': 1,
          'to': 1,
          'working': 1,
          'you': 1}),
 Counter({'@BokehPlots': 1,
          '@anacondainc': 1,
          '@bigreddot': 1,
          '@pwang': 1,
          'Congrats': 1,
          'and': 1,
          'for': 1,
          'releasing': 1,
          'team': 1,
          'the': 1,
          'to': 1}),
 Counter({'@BokehPlots': 1,
          '@anacondainc': 1,
          '@bigreddot': 1,
          '@hugobowne': 1,
          '@pwang': 1,
          'Congrats': 1,
          'RT': 1,
          'So': 1,
          'excited': 1,
          'out': 1,
          'see': 1,
          'team': 1,
          'the': 1,
          'there': 1,
          'to': 2,
          'whole': 1}),
 Counter({'#API': 1,
          'APIs': 1,
          'Learn': 1,
          'Learning': 1,
          'Machine': 1,
          'Models': 1,
          'New': 1,
          'Python': 1,
          'Turning': 1,
          'Tutorial': 1,
          'a': 2,
          'create': 1,
          'from': 1,
          'how': 1,
          'in': 1,
          'into': 1,
          'mach': 1,
          'simple': 1,
          'to': 2}),
 Counter({'#Python': 1,
          '#data': 1,
          '#geospatial': 1,
          '#plot': 1,
          'Data': 1,
          'Geospatial': 1,
          'In': 1,
          'Introduction': 1,
          'New': 1,
          'Tutorial': 1,
          'in': 1,
          'this': 1,
          'to': 2,
          'tutorial': 1,
          'use': 1,
          'will': 1,
          'you': 1}),
 Counter({'@hugobowne': 1,
          'Brian': 1,
          'Chatting': 1,
          'RT': 1,
          'Stoked': 1,
          'a': 1,
          'always': 1,
          'and': 1,
          'full': 1,
          'fun': 1,
          'have': 1,
          'insight': 1,
          'is': 1,
          'it': 1,
          'lot': 1,
          'of': 2,
          'out': 1,
          'put': 1,
          'recorded': 1,
          'there': 1,
          'this': 1,
          'to': 1,
          'w': 1}),
 Counter({'#rstats': 1,
          '@DataCamp': 1,
          '@kyle': 1,
          '@uscensusbureau': 1,
          'I': 1,
          'RT': 1,
          'Take': 1,
          'co': 1,
          'course': 1,
          'data': 1,
          'e': 1,
          'excited': 1,
          'has': 1,
          'in': 1,
          'launched': 1,
          'm': 1,
          'my': 1,
          'on': 1,
          'share': 1,
          'that': 1,
          'the': 1,
          'to': 1,
          'walker': 1,
          'with': 1,
          'working': 1}),
 Counter({'@kyle': 1,
          'Analyzing': 1,
          'Census': 1,
          'Course': 1,
          'Data': 1,
          'In': 1,
          'New': 1,
          'R': 1,
          'US': 1,
          'able': 1,
          'be': 1,
          'by': 1,
          'course': 1,
          'e': 1,
          'in': 1,
          'll': 1,
          'rapidly': 1,
          'this': 1,
          'to': 1,
          'visualize': 1,
          'walker': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@googlecloud': 1,
          '@hugobowne': 1,
          '@quaesita': 1,
          'Chief': 1,
          'Decision': 1,
          'Ep': 1,
          'I': 1,
          'In': 1,
          'RT': 1,
          'Scientist': 1,
          'about': 1,
          'decision': 1,
          'mak': 1,
          'of': 1,
          'pod': 1,
          'speak': 1,
          'the': 1,
          'w': 1}),
 Counter({'#datascience': 1,
          '@DATACAMP': 1,
          '@venturidb': 1,
          'A': 1,
          'CONS': 1,
          'CREATING': 1,
          'Impact': 1,
          'OF': 1,
          'PROJECT': 1,
          'PROS': 2,
          'RT': 1,
          'a': 1,
          'audience': 1,
          'brand': 1,
          'build': 1,
          'global': 1,
          'in': 1,
          'supplement': 1,
          'your': 2}),
 Counter({'@PFF': 1,
          'Eric': 1,
          'I': 1,
          'If': 1,
          'PFF': 1,
          'RT': 1,
          'This': 1,
          'UWL': 1,
          'a': 1,
          'and': 1,
          'at': 2,
          'b': 1,
          'between': 1,
          'cool': 1,
          'full': 1,
          'in': 1,
          'interested': 1,
          'my': 1,
          'of': 1,
          'one': 1,
          're': 1,
          'started': 1,
          'starting': 1,
          'the': 1,
          'thing': 1,
          'time': 2,
          'was': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@ProjectJupyter': 1,
          '@ellisonbg': 1,
          '@hugobowne': 1,
          'I': 1,
          'RT': 1,
          'about': 1,
          'for': 1,
          'intera': 1,
          'open': 1,
          'podcast': 1,
          'recently': 1,
          'software': 1,
          'source': 1,
          'spoke': 1,
          'the': 1,
          'with': 1}),
 Counter({'@PFF': 1,
          '@old': 1,
          'Eric': 1,
          'Love': 1,
          'RT': 1,
          'What': 1,
          'by': 1,
          'chester': 1,
          'coding': 1,
          'course': 1,
          'in': 1,
          'interactive': 1,
          'like': 1,
          'man': 1,
          'mathematical': 1,
          'other': 1,
          'see': 1,
          'taught': 1,
          'this': 2,
          'to': 1,
          'topics': 1,
          'would': 1,
          'you': 1}),
 Counter({'@PFF': 1,
          'Algebra': 1,
          'Course': 1,
          'Data': 1,
          'Eric': 1,
          'In': 1,
          'Linear': 1,
          'New': 1,
          'R': 1,
          'Science': 1,
          'by': 1,
          'course': 1,
          'for': 1,
          'how': 1,
          'in': 1,
          'learn': 1,
          'll': 1,
          'this': 1,
          'to': 1,
          'vector': 1,
          'with': 1,
          'work': 1,
          'you': 1}),
 Counter({'#rstats': 1,
          '@DataCamp': 1,
          '@noamross': 1,
          'Additive': 1,
          'GAMs': 1,
          'Generalized': 1,
          'Jazzed': 1,
          'Learn': 1,
          'Mode': 1,
          'Modeling': 1,
          'Nonlinear': 1,
          'RT': 1,
          'course': 1,
          'in': 1,
          'launch': 1,
          'my': 1,
          'new': 1,
          'on': 1,
          'to': 2,
          'use': 1,
          'with': 1}),
 Counter({'@noamross': 1,
          'Course': 1,
          'GAMs': 2,
          'In': 1,
          'Modeling': 1,
          'New': 1,
          'Nonlinear': 1,
          'R': 1,
          'by': 1,
          'con': 1,
          'course': 1,
          'how': 2,
          'in': 1,
          'learn': 1,
          'll': 1,
          'this': 1,
          'to': 1,
          'with': 1,
          'work': 1,
          'you': 1}),
 Counter({'@Rbloggers': 1,
          'Cassie': 1,
          'Kozyrkov': 1,
          'RT': 1,
          'and': 1,
          'decision': 2,
          'discusses': 1,
          'intelligence': 1,
          'making': 1}),
 Counter({'@HarvardBiz': 1,
          '@hugobowne': 1,
          'I': 1,
          'RT': 1,
          'Watc': 1,
          'a': 1,
          'about': 1,
          'been': 1,
          'can': 1,
          'century': 1,
          'data': 1,
          'down': 1,
          'for': 1,
          'it': 1,
          'like': 1,
          'literacy': 1,
          'look': 1,
          'lot': 1,
          'st': 1,
          'started': 1,
          'thinking': 1,
          've': 1,
          'what': 1,
          'writing': 1}),
 Counter({'@BillBrazell': 1,
          '@hugobowne': 1,
          'Captured': 1,
          'Data': 2,
          'Depends': 1,
          'How': 1,
          'Literacy': 1,
          'RT': 1,
          'They': 1,
          'Types': 1,
          'Understanding': 1,
          'Your': 1,
          'of': 1,
          'on': 1,
          're': 1,
          'says': 1,
          'the': 1}),
 Counter({'@Rbloggers': 1,
          'Best': 1,
          'Course': 1,
          'New': 1,
          'Practices': 1,
          'R': 1,
          'RT': 1,
          'Visualization': 1,
          'in': 1}),
 Counter({'@Rbloggers': 1,
          'Course': 1,
          'Data': 1,
          'Interactive': 1,
          'New': 1,
          'RT': 1,
          'Visualization': 1,
          'rbokeh': 1,
          'with': 1}),
 Counter({'#Python': 1,
          '#Stemming': 1,
          'Lemmatization': 1,
          'New': 1,
          'Stemming': 1,
          'This': 1,
          'Tutorial': 1,
          'and': 1,
          'covers': 1,
          'in': 1,
          'introduction': 1,
          'the': 1,
          'to': 1,
          'tutorial': 1}),
 Counter({'@DataCamp': 1,
          '@mona': 1,
          'RT': 1,
          'What': 1,
          'at': 1,
          'do': 1,
          'khm': 1,
          'learn': 1,
          'next': 1,
          'to': 1,
          'want': 1,
          'you': 1}),
 Counter({'@DataCamp': 1,
          '@andrea': 1,
          'I': 1,
          'RT': 1,
          'agree': 1,
          'amazing': 1,
          'animals': 1,
          'is': 1}),
 Counter({'#DataFramed': 1,
          '@googlecloud': 1,
          '@hugobowne': 1,
          '@quaesita': 1,
          'Chief': 1,
          'Decision': 1,
          'Episode': 1,
          'New': 1,
          'Scientist': 1,
          'about': 1,
          'at': 1,
          'decisio': 1,
          'speaks': 1,
          'with': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@Pro': 1,
          '@ellisonbg': 1,
          '@hugobowne': 1,
          'Ep': 1,
          'RT': 1,
          'computing': 1,
          'contributed': 1,
          'has': 1,
          'interactive': 1,
          'of': 2,
          'podcast': 1,
          'rise': 1,
          'the': 2,
          'to': 1,
          'w': 1,
          'what': 1}),
 Counter({'AdWords': 1,
          'Engine': 1,
          'Google': 1,
          'In': 1,
          'Marketing': 1,
          'Search': 1,
          'by': 1,
          'campaigns': 1,
          'create': 1,
          'data': 1,
          'generatin': 1,
          'learn': 1,
          'meets': 1,
          'science': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1}),
 Counter({'Building': 1,
          'Chatbots': 1,
          'Learn': 1,
          'Python': 1,
          'based': 1,
          'how': 1,
          'human': 1,
          'in': 1,
          'instructions': 1,
          'into': 1,
          'language': 1,
          'm': 1,
          'machine': 1,
          'rule': 1,
          'systems': 1,
          'to': 1,
          'turn': 1,
          'with': 1}),
 Counter({'Analysis': 1,
          'Data': 1,
          'Dive': 1,
          'EDA': 1,
          'Exploratory': 1,
          'Prince': 1,
          'R': 1,
          'and': 1,
          'insight': 1,
          'into': 1,
          'lyrics': 1,
          'mining': 1,
          'music': 1,
          'of': 1,
          's': 1,
          'shed': 1,
          'text': 1,
          'the': 1,
          'to': 1,
          'use': 1,
          'with': 1}),
 Counter({'They': 1,
          'This': 1,
          'a': 2,
          'course': 1,
          'how': 1,
          'is': 1,
          'leverage': 1,
          'of': 1,
          'picture': 1,
          'power': 1,
          'say': 1,
          'teaches': 1,
          'that': 1,
          'the': 2,
          'thousand': 1,
          'tidyver': 1,
          'to': 1,
          'words': 1,
          'worth': 1,
          'you': 1}),
 Counter({'Learn': 1,
          'apply': 1,
          'clicks': 1,
          'factorization': 1,
          'how': 1,
          'hundreds': 1,
          'in': 1,
          'matrix': 1,
          'names': 1,
          'of': 1,
          'on': 2,
          'recommender': 1,
          'system': 1,
          'the': 1,
          'to': 1,
          'user': 1}),
 Counter({'An': 1,
          'Cloud': 1,
          'Compute': 1,
          'Engine': 1,
          'Google': 2,
          'Learn': 1,
          'a': 1,
          'an': 1,
          'create': 1,
          'data': 1,
          'environment': 1,
          'install': 1,
          'instance': 1,
          'on': 2,
          'science': 1,
          'set': 1,
          'to': 1,
          'up': 1}),
 Counter({'@DataCamp': 1,
          '@OmaymaS': 1,
          'And': 1,
          'RT': 1,
          'Thanks': 1,
          'beta': 1,
          'course': 1,
          'during': 1,
          'everyone': 1,
          'here': 1,
          'me': 1,
          'months': 1,
          'my': 1,
          'on': 1,
          'previous': 1,
          's': 1,
          'testers': 1,
          'the': 2,
          'to': 2,
          'w': 1,
          'who': 1,
          'with': 1,
          'worked': 1}),
 Counter({'GUI': 1,
          'In': 2,
          'Introduction': 1,
          'New': 1,
          'Python': 1,
          'Tkinter': 1,
          'To': 1,
          'Tutorial': 1,
          'With': 1,
          'are': 1,
          'create': 1,
          'going': 1,
          'how': 1,
          'learn': 1,
          'this': 1,
          'to': 2,
          'tutorial': 1,
          'you': 1}),
 Counter({'#Python': 1,
          '#probability': 1,
          'Distributions': 1,
          'In': 1,
          'New': 1,
          'Probability': 1,
          'Tutorial': 1,
          'about': 1,
          'commonly': 1,
          'in': 1,
          'learn': 1,
          'll': 1,
          'this': 1,
          'tutorial': 1,
          'used': 1,
          'you': 1}),
 Counter({'#PyDataNYC': 1,
          '#python': 1,
          '@DataCamp': 1,
          '@ProjectJupy': 1,
          '@ellisonbg': 1,
          '@hugobowne': 1,
          'Got': 1,
          'RT': 1,
          'a': 2,
          'about': 1,
          'at': 1,
          'back': 1,
          'gave': 1,
          'my': 1,
          'pod': 1,
          'released': 1,
          'roots': 1,
          'talk': 1,
          'this': 1,
          'to': 1,
          'w': 1,
          'week': 1}),
 Counter({'Analysis': 2,
          'Learn': 1,
          'New': 1,
          'R': 3,
          'Series': 2,
          'Time': 2,
          'Tutorial': 1,
          'a': 1,
          'along': 1,
          'f': 1,
          'for': 1,
          'in': 1,
          'package': 1,
          'using': 2,
          'with': 2}),
 Counter({'#dataviz': 1,
          '#rstats': 1,
          '@NicholasStrayer': 1,
          'DataCamp': 1,
          'Help': 1,
          'It': 1,
          'RT': 1,
          'a': 1,
          'bring': 1,
          'course': 1,
          'giant': 1,
          'honor': 1,
          'launch': 1,
          'lev': 1,
          'my': 1,
          'next': 1,
          'on': 1,
          'pretty': 1,
          's': 1,
          'skills': 1,
          'the': 1,
          'to': 2,
          'viz': 1,
          'your': 1}),
 Counter({'#biostatistician': 1,
          '@NicholasStrayer': 1,
          '@VanderbiltU': 1,
          'Check': 1,
          'Hi': 1,
          'a': 1,
          'by': 1,
          'course': 1,
          'currently': 1,
          'data': 1,
          'is': 1,
          'new': 1,
          'out': 1,
          'scientist': 1,
          'this': 1,
          'who': 1}),
 Counter({'#Halloween': 1,
          '@NickSolomon': 1,
          'Candy': 1,
          'Explore': 1,
          'Get': 1,
          'Halloween': 1,
          'New': 1,
          'Project': 1,
          'Rankings': 1,
          'by': 2,
          'in': 1,
          's': 1,
          'spirit': 1,
          'taking': 1,
          'the': 1,
          'this': 1}),
 Counter({'#DataFramed': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@quaesita': 1,
          'Chief': 1,
          'Decision': 1,
          'RT': 1,
          'Sc': 1,
          'You': 1,
          'a': 1,
          'conversation': 1,
          'ep': 1,
          'miss': 1,
          'next': 1,
          'of': 1,
          'podcast': 1,
          's': 1,
          't': 1,
          'the': 1,
          'to': 1,
          'w': 1,
          'want': 1,
          'week': 1,
          'won': 1}),
 Counter({'@richierocks': 1,
          'Food': 1,
          'Forecasts': 1,
          'Functions': 1,
          'In': 1,
          'New': 1,
          'Price': 1,
          'Project': 1,
          'by': 1,
          'for': 1,
          'practice': 1,
          'project': 1,
          'this': 1,
          'will': 1,
          'writing': 1,
          'you': 1}),
 Counter({'@teeniedeenie': 1,
          'Finance': 1,
          'Her': 1,
          'Intro': 1,
          'Iowa': 1,
          'Python': 1,
          'State': 1,
          'Take': 1,
          'University': 1,
          'at': 1,
          'by': 1,
          'course': 1,
          'foc': 1,
          'for': 1,
          'new': 1,
          'research': 1,
          'taught': 1,
          'this': 1,
          'to': 1}),
 Counter({'@fjsosah': 1,
          'Thank': 1,
          'We': 1,
          'attention': 1,
          'bringing': 1,
          'for': 1,
          'into': 1,
          'it': 2,
          'look': 1,
          'our': 1,
          'to': 1,
          'will': 1,
          'you': 1}),
 Counter({'#DataFramed': 1,
          '#PyDataNYC': 1,
          '#datascience': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          'I': 2,
          'RT': 1,
          'a': 1,
          'about': 1,
          'at': 1,
          'discovered': 1,
          'gave': 1,
          'hey': 1,
          'hosting': 1,
          'just': 1,
          'on': 1,
          'po': 1,
          'talk': 1,
          'the': 1,
          've': 1,
          'what': 1,
          'while': 1}),
 Counter({'#PyDataNYC': 1,
          '@DataCamp': 1,
          '@hugobowne': 1,
          '@seanmylaw': 1,
          'RT': 1,
          'data': 1,
          'do': 1,
          'figure': 1,
          'from': 1,
          'helping': 1,
          'out': 1,
          'really': 1,
          'scientists': 1,
          'us': 1,
          'what': 1}),
 Counter({'#algorithms': 1,
          '#rbokeh': 1,
          'Data': 1,
          'Omayma': 1,
          'Said': 1,
          'She': 1,
          'Take': 1,
          'Visualization': 1,
          'by': 1,
          'course': 1,
          'developing': 1,
          'has': 1,
          'new': 1,
          'on': 1,
          'our': 1,
          'taught': 1,
          'with': 1,
          'worked': 1}),
 Counter({'@teeniedeenie': 1,
          'Course': 1,
          'Finance': 1,
          'Intro': 1,
          'New': 1,
          'Python': 2,
          'The': 1,
          'adopting': 1,
          'by': 1,
          'financial': 1,
          'fo': 1,
          'for': 1,
          'increasingly': 1,
          'industry': 1,
          'is': 1,
          'to': 1}),
 Counter({'@DataCamp': 1,
          '@Leuven': 1,
          'De': 1,
          'Dieter': 1,
          'How': 1,
          'Mesmaeker': 1,
          'MindGate': 1,
          'On': 1,
          'Our': 1,
          'RT': 1,
          'a': 1,
          'are': 1,
          'can': 1,
          'data': 1,
          'ddmkr': 1,
          'from': 1,
          'is': 1,
          'on': 1,
          'people': 1,
          'roll': 1,
          'sc': 1,
          'speakers': 1,
          'stage': 1,
          'teach': 1,
          'we': 1}),
 Counter({'@DataCamp': 1,
          '@drewconway': 1,
          '@ed': 1,
          'Data': 1,
          'March': 1,
          'Nice': 1,
          'RT': 1,
          'Science': 1,
          'They': 1,
          'Venn': 1,
          'berry': 1,
          'diagram': 1,
          'emphasise': 1,
          'episode': 1,
          'famous': 1,
          'from': 1,
          'is': 1,
          'n': 1,
          'of': 2,
          'podcast': 1,
          's': 1,
          'the': 1,
          'with': 1}),
 Counter({'#data': 1,
          '@NicholasStrayer': 1,
          'Best': 1,
          'Course': 1,
          'New': 1,
          'Practices': 1,
          'R': 1,
          'This': 1,
          'Visualization': 1,
          'by': 1,
          'course': 1,
          'help': 1,
          'in': 1,
          'take': 1,
          'will': 1,
          'you': 1,
          'your': 1}),
 Counter({'@DataCamp': 1,
          '@mona': 1,
          'I': 1,
          'RT': 1,
          'SQL': 1,
          'a': 1,
          'about': 1,
          'and': 1,
          'are': 1,
          'blog': 1,
          'can': 1,
          'differences': 1,
          'for': 1,
          'help': 1,
          'how': 1,
          'khm': 1,
          'learning': 1,
          'on': 1,
          'post': 1,
          's': 1,
          'start': 1,
          'the': 1,
          'to': 1,
          'we': 1,
          'what': 1,
          'where': 1,
          'wrote': 1,
          'you': 1}),
 Counter({'@datacamp': 1,
          '@dunjanik': 1,
          'Hi': 1,
          'They': 1,
          'able': 1,
          'be': 1,
          'com': 1,
          'contact': 1,
          'help': 1,
          'please': 1,
          'problem': 1,
          'specific': 1,
          'support': 1,
          'to': 1,
          'will': 1,
          'with': 1,
          'you': 1,
          'your': 1}),
 Counter({'Course': 1,
          'Data': 2,
          'Interactive': 1,
          'New': 1,
          'Omayma': 1,
          'Said': 1,
          'Visualization': 1,
          'an': 1,
          'by': 1,
          'integral': 1,
          'is': 1,
          'of': 1,
          'part': 1,
          'rbokeh': 1,
          'th': 1,
          'visualization': 1,
          'with': 1}),
 Counter({'@DataCamp': 1,
          '@manideeplanka': 1,
          'RT': 1,
          'and': 1,
          'animation': 1,
          'are': 1,
          'as': 2,
          'beautiful': 1,
          'courses': 1,
          'is': 1,
          'this': 1,
          'wonderful': 1,
          'your': 1}),
 Counter({'#Python': 1,
          '#decorators': 1,
          'Decorators': 1,
          'In': 1,
          'New': 1,
          'Python': 1,
          'Tutorial': 1,
          'how': 1,
          'implement': 1,
          'in': 2,
          'learn': 1,
          'this': 1,
          'to': 1,
          'tutorial': 1}),
 Counter({'@DataCamp': 1,
          '@drob': 1,
          'DataCamp': 1,
          'Instructor': 1,
          'Intern': 1,
          'RT': 1,
          'Recruiting': 1,
          'We': 1,
          'about': 1,
          'an': 1,
          'at': 1,
          'enthusiastic': 1,
          'find': 1,
          'for': 1,
          'great': 2,
          'hiring': 1,
          're': 1,
          'someone': 1,
          'to': 1,
          'wants': 1,
          'who': 1}),
 Counter({'#SQLite': 1,
          'Date': 1,
          'Functions': 1,
          'Hacking': 1,
          'Read': 1,
          'in': 1,
          'new': 1,
          'on': 1,
          'our': 1,
          'tutorial': 1})]

# %%
word_counts = [Counter({'#SQLite': 11,
                       'Date': 16,
                          'Functions': 5,
                          'Hacking': 1,
                          'Read': 1,
                          'in': 1,
                          'new': 2,
                          'on': 3,
                          'our': 1,
                          'tutorial': 1})]

# Import local package
import text_analyzer

# Sum word_counts using sum_counters from text_analyzer
word_count_totals = text_analyzer.sum_counters(word_counts)

# Plot word_count_totals using plot_counter from text_analyzer
text_analyzer.plot_counter(word_count_totals)

# %%
# Import needed function from setuptools
from setuptools import setup

# Create proper setup to be used by pip
setup(name='text_analyzer',
      version='0.0.1',
      description='Perform and visualize a text anaylsis.',
      author='bos',
      packages=['text_analyzer'])
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: usage: ipykernel_launcher.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#    or: ipykernel_launcher.py --help [cmd1 cmd2 ...]
#    or: ipykernel_launcher.py --help-commands
#    or: ipykernel_launcher.py cmd --help
#
# error: option -f not recognized
# /Users/Brian/anaconda3/envs/datacamp/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Import needed function from setuptools
from setuptools import setup

# Create proper setup to be used by pip
setup(name='text_analyzer',
      version='0.0.1',
      description='Perform and visualize a text anaylsis.',
      author='username',
      packages=['text_analyzer'],
      install_requires=['matplotlib>=3.0.0'])
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: usage: ipykernel_launcher.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#    or: ipykernel_launcher.py --help [cmd1 cmd2 ...]
#    or: ipykernel_launcher.py --help-commands
#    or: ipykernel_launcher.py cmd --help
#
# error: option -f not recognized
# /Users/Brian/anaconda3/envs/datacamp/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
